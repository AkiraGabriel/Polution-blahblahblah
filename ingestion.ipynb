# %%
import requests
import pandas as pd
import os

# %%
API_KEY = os.getenv('API_KEY')

# %%
lat = -23.56134513800555
lon = -46.65586044541178

# %%
url = f'http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={API_KEY}'

# %%
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
else:
    print(f'Erro na requisição: {response.status_code}')

# %%
data['list']
# Out:
# [{'main': {'aqi': 2},
#   'components': {'co': 680.92,
#    'no': 0.67,
#    'no2': 20.56,
#    'o3': 4.16,
#    'so2': 4.65,
#    'pm2_5': 24.18,
#    'pm10': 40.95,
#    'nh3': 1.92},
#   'dt': 1737864000},
#  {'main': {'aqi': 2},
#   'components': {'co': 634.19,
#    'no': 0.63,
#    'no2': 21.42,
#    'o3': 3.89,
#    'so2': 6.44,
#    'pm2_5': 23,
#    'pm10': 40.23,
#    'nh3': 3.17},
#   'dt': 1737867600},
#  {'main': {'aqi': 2},
#   'components': {'co': 634.19,
#    'no': 1.09,
#    'no2': 23.99,
#    'o3': 2.19,
#    'so2': 8.7,
#    'pm2_5': 23.64,
#    'pm10': 40.64,
#    'nh3': 4.5},
#   'dt': 1737871200},
#  {'main': {'aqi': 3},
#   'components': {'co': 674.25,
#    'no': 2.65,
#    'no2': 27.08,
#    'o3': 0.57,
#    'so2': 11.44,
#    'pm2_5': 27.29,
#    'pm10': 44.53,
#    'nh3': 5.83},
#   'dt': 1737874800},
#  {'main': {'aqi': 3},
#   'components': {'co': 741.01,
#    'no': 6.04,
#    'no2': 29.82,
#    'o3': 0.07,
#    'so2': 14.07,
#    'pm2_5': 32.34,
#    'pm10': 50.52,
#    'nh3': 7.09},
#   'dt': 1737878400},
#  {'main': {'aqi': 3},
#   'components': {'co': 881.2,
#    'no': 16.54,
#    'no2': 31.53,
#    'o3': 0,
#    'so2': 16.69,
#    'pm2_5': 39.58,
#    'pm10': 59.87,
#    'nh3': 8.36},
#   'dt': 1737882000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1201.63,
#    'no': 41.13,
#    'no2': 28.45,
#    'o3': 0.18,
#    'so2': 15.14,
#    'pm2_5': 49.36,
#    'pm10': 71.29,
#    'nh3': 6.27},
#   'dt': 1737885600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1508.71,
#    'no': 61.69,
#    'no2': 27.76,
#    'o3': 1.74,
#    'so2': 11.92,
#    'pm2_5': 55.94,
#    'pm10': 81.63,
#    'nh3': 3.52},
#   'dt': 1737889200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1575.47,
#    'no': 48.28,
#    'no2': 45.93,
#    'o3': 12.7,
#    'so2': 10.49,
#    'pm2_5': 62.75,
#    'pm10': 91.94,
#    'nh3': 2.85},
#   'dt': 1737892800},
#  {'main': {'aqi': 3},
#   'components': {'co': 714.3,
#    'no': 2.04,
#    'no2': 20.91,
#    'o3': 121.59,
#    'so2': 14.78,
#    'pm2_5': 34.72,
#    'pm10': 55.95,
#    'nh3': 7.54},
#   'dt': 1737896400},
#  {'main': {'aqi': 3},
#   'components': {'co': 554.09,
#    'no': 0.52,
#    'no2': 9.68,
#    'o3': 130.18,
#    'so2': 9.06,
#    'pm2_5': 20.83,
#    'pm10': 35.41,
#    'nh3': 4.94},
#   'dt': 1737900000},
#  {'main': {'aqi': 3},
#   'components': {'co': 514.03,
#    'no': 0.16,
#    'no2': 8.65,
#    'o3': 118.73,
#    'so2': 7.45,
#    'pm2_5': 16.76,
#    'pm10': 29.59,
#    'nh3': 3.9},
#   'dt': 1737903600},
#  {'main': {'aqi': 2},
#   'components': {'co': 473.98,
#    'no': 0,
#    'no2': 8.4,
#    'o3': 95.84,
#    'so2': 5.66,
#    'pm2_5': 12.52,
#    'pm10': 23.02,
#    'nh3': 2.91},
#   'dt': 1737907200},
#  {'main': {'aqi': 2},
#   'components': {'co': 507.36,
#    'no': 0,
#    'no2': 11.82,
#    'o3': 81.54,
#    'so2': 6.91,
#    'pm2_5': 13.03,
#    'pm10': 23.66,
#    'nh3': 3.58},
#   'dt': 1737910800},
#  {'main': {'aqi': 2},
#   'components': {'co': 660.9,
#    'no': 0.01,
#    'no2': 21.94,
#    'o3': 72.24,
#    'so2': 12.76,
#    'pm2_5': 19.89,
#    'pm10': 33.94,
#    'nh3': 6.08},
#   'dt': 1737914400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1001.36,
#    'no': 0.02,
#    'no2': 46.61,
#    'o3': 53.64,
#    'so2': 24.56,
#    'pm2_5': 36.32,
#    'pm10': 57.01,
#    'nh3': 9.63},
#   'dt': 1737918000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1415.25,
#    'no': 0.05,
#    'no2': 80.2,
#    'o3': 23.25,
#    'so2': 34.81,
#    'pm2_5': 55.63,
#    'pm10': 81.81,
#    'nh3': 10.26},
#   'dt': 1737921600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1695.63,
#    'no': 1.96,
#    'no2': 105.56,
#    'o3': 3.71,
#    'so2': 39.58,
#    'pm2_5': 66.88,
#    'pm10': 93.61,
#    'nh3': 8.99},
#   'dt': 1737925200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1762.39,
#    'no': 7.82,
#    'no2': 111.04,
#    'o3': 0.06,
#    'so2': 38.15,
#    'pm2_5': 64.87,
#    'pm10': 88.35,
#    'nh3': 8.36},
#   'dt': 1737928800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1602.17,
#    'no': 11.06,
#    'no2': 98.71,
#    'o3': 0,
#    'so2': 33.38,
#    'pm2_5': 52.88,
#    'pm10': 72.11,
#    'nh3': 7.54},
#   'dt': 1737932400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1415.25,
#    'no': 11.51,
#    'no2': 85,
#    'o3': 0,
#    'so2': 29.09,
#    'pm2_5': 42.62,
#    'pm10': 59,
#    'nh3': 6.65},
#   'dt': 1737936000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1255.04,
#    'no': 10.39,
#    'no2': 70.6,
#    'o3': 0.01,
#    'so2': 23.6,
#    'pm2_5': 37.55,
#    'pm10': 52.72,
#    'nh3': 5.19},
#   'dt': 1737939600},
#  {'main': {'aqi': 3},
#   'components': {'co': 1134.87,
#    'no': 9.16,
#    'no2': 57.58,
#    'o3': 0.02,
#    'so2': 18.84,
#    'pm2_5': 35.85,
#    'pm10': 49.59,
#    'nh3': 4.05},
#   'dt': 1737943200},
#  {'main': {'aqi': 3},
#   'components': {'co': 1081.47,
#    'no': 8.72,
#    'no2': 51.41,
#    'o3': 0.03,
#    'so2': 16.93,
#    'pm2_5': 34.99,
#    'pm10': 49.09,
#    'nh3': 4.02},
#   'dt': 1737946800},
#  {'main': {'aqi': 3},
#   'components': {'co': 1081.47,
#    'no': 10.51,
#    'no2': 45.93,
#    'o3': 0.01,
#    'so2': 14.78,
#    'pm2_5': 37.14,
#    'pm10': 52.79,
#    'nh3': 3.36},
#   'dt': 1737950400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1094.82,
#    'no': 13.75,
#    'no2': 39.41,
#    'o3': 0,
#    'so2': 12.4,
#    'pm2_5': 40.92,
#    'pm10': 57.97,
#    'nh3': 2.88},
#   'dt': 1737954000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1108.17,
#    'no': 16.99,
#    'no2': 34.96,
#    'o3': 0,
#    'so2': 12.04,
#    'pm2_5': 44.87,
#    'pm10': 63.55,
#    'nh3': 3.14},
#   'dt': 1737957600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1161.58,
#    'no': 22.13,
#    'no2': 33.59,
#    'o3': 0,
#    'so2': 13.11,
#    'pm2_5': 50.81,
#    'pm10': 71.11,
#    'nh3': 3.93},
#   'dt': 1737961200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1241.68,
#    'no': 29.5,
#    'no2': 33.24,
#    'o3': 0,
#    'so2': 14.19,
#    'pm2_5': 57.62,
#    'pm10': 79.07,
#    'nh3': 4.5},
#   'dt': 1737964800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1388.55,
#    'no': 43.81,
#    'no2': 32.56,
#    'o3': 0,
#    'so2': 15.26,
#    'pm2_5': 65.33,
#    'pm10': 88.36,
#    'nh3': 5.19},
#   'dt': 1737968400},
#  {'main': {'aqi': 4},
#   'components': {'co': 1642.23,
#    'no': 67.95,
#    'no2': 32.22,
#    'o3': 0,
#    'so2': 16.45,
#    'pm2_5': 70.67,
#    'pm10': 94.57,
#    'nh3': 5.45},
#   'dt': 1737972000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1682.28,
#    'no': 77.78,
#    'no2': 28.1,
#    'o3': 0.01,
#    'so2': 14.19,
#    'pm2_5': 66.35,
#    'pm10': 90.87,
#    'nh3': 4.12},
#   'dt': 1737975600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1428.6,
#    'no': 62.59,
#    'no2': 25.36,
#    'o3': 0.04,
#    'so2': 11.92,
#    'pm2_5': 53.07,
#    'pm10': 78.49,
#    'nh3': 3.39},
#   'dt': 1737979200},
#  {'main': {'aqi': 2},
#   'components': {'co': 734.33,
#    'no': 14.75,
#    'no2': 29.13,
#    'o3': 3.98,
#    'so2': 11.33,
#    'pm2_5': 20.91,
#    'pm10': 42.57,
#    'nh3': 4.56},
#   'dt': 1737982800},
#  {'main': {'aqi': 2},
#   'components': {'co': 560.76,
#    'no': 4.19,
#    'no2': 28.45,
#    'o3': 10.82,
#    'so2': 9.54,
#    'pm2_5': 11.99,
#    'pm10': 29.92,
#    'nh3': 4.12},
#   'dt': 1737986400},
#  {'main': {'aqi': 2},
#   'components': {'co': 500.68,
#    'no': 1.76,
#    'no2': 26.73,
#    'o3': 19.31,
#    'so2': 8.7,
#    'pm2_5': 8.94,
#    'pm10': 24.31,
#    'nh3': 4.12},
#   'dt': 1737990000},
#  {'main': {'aqi': 1},
#   'components': {'co': 423.91,
#    'no': 0.44,
#    'no2': 16.11,
#    'o3': 35.05,
#    'so2': 4.95,
#    'pm2_5': 5.35,
#    'pm10': 13.61,
#    'nh3': 2.38},
#   'dt': 1737993600},
#  {'main': {'aqi': 1},
#   'components': {'co': 433.92,
#    'no': 0.19,
#    'no2': 16.11,
#    'o3': 37.91,
#    'so2': 5.01,
#    'pm2_5': 5.23,
#    'pm10': 12.28,
#    'nh3': 2.38},
#   'dt': 1737997200},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.12,
#    'no2': 19.36,
#    'o3': 35.05,
#    'so2': 6.32,
#    'pm2_5': 6.04,
#    'pm10': 13.6,
#    'nh3': 2.91},
#   'dt': 1738000800},
#  {'main': {'aqi': 1},
#   'components': {'co': 514.03,
#    'no': 0.11,
#    'no2': 24.68,
#    'o3': 29.33,
#    'so2': 7.87,
#    'pm2_5': 6.99,
#    'pm10': 15.83,
#    'nh3': 3.42},
#   'dt': 1738004400},
#  {'main': {'aqi': 1},
#   'components': {'co': 567.44,
#    'no': 0.18,
#    'no2': 30.85,
#    'o3': 22.89,
#    'so2': 9.54,
#    'pm2_5': 8.01,
#    'pm10': 18.48,
#    'nh3': 3.67},
#   'dt': 1738008000},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 0.31,
#    'no2': 34.62,
#    'o3': 19.13,
#    'so2': 10.97,
#    'pm2_5': 8.95,
#    'pm10': 20.82,
#    'nh3': 3.67},
#   'dt': 1738011600},
#  {'main': {'aqi': 2},
#   'components': {'co': 674.25,
#    'no': 1.17,
#    'no2': 41.13,
#    'o3': 8.67,
#    'so2': 12.4,
#    'pm2_5': 12.35,
#    'pm10': 26.32,
#    'nh3': 3.39},
#   'dt': 1738015200},
#  {'main': {'aqi': 2},
#   'components': {'co': 794.41,
#    'no': 5.81,
#    'no2': 42.84,
#    'o3': 0.53,
#    'so2': 12.88,
#    'pm2_5': 17.61,
#    'pm10': 33.21,
#    'nh3': 3.07},
#   'dt': 1738018800},
#  {'main': {'aqi': 2},
#   'components': {'co': 921.25,
#    'no': 14.31,
#    'no2': 39.76,
#    'o3': 0.01,
#    'so2': 13.35,
#    'pm2_5': 23.3,
#    'pm10': 39.61,
#    'nh3': 3.2},
#   'dt': 1738022400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1028.06,
#    'no': 22.58,
#    'no2': 37.01,
#    'o3': 0,
#    'so2': 14.07,
#    'pm2_5': 28.96,
#    'pm10': 45.96,
#    'nh3': 3.74},
#   'dt': 1738026000},
#  {'main': {'aqi': 3},
#   'components': {'co': 961.3,
#    'no': 21.68,
#    'no2': 32.22,
#    'o3': 0,
#    'so2': 11.56,
#    'pm2_5': 27.96,
#    'pm10': 44.5,
#    'nh3': 3.14},
#   'dt': 1738029600},
#  {'main': {'aqi': 2},
#   'components': {'co': 767.71,
#    'no': 13.3,
#    'no2': 26.73,
#    'o3': 0.02,
#    'so2': 7.87,
#    'pm2_5': 21.47,
#    'pm10': 36.61,
#    'nh3': 2.09},
#   'dt': 1738033200},
#  {'main': {'aqi': 2},
#   'components': {'co': 574.11,
#    'no': 3.58,
#    'no2': 21.94,
#    'o3': 0.85,
#    'so2': 4.89,
#    'pm2_5': 14.01,
#    'pm10': 26.7,
#    'nh3': 1.36},
#   'dt': 1738036800},
#  {'main': {'aqi': 2},
#   'components': {'co': 480.65,
#    'no': 0.7,
#    'no2': 17.99,
#    'o3': 3.26,
#    'so2': 4.05,
#    'pm2_5': 11.03,
#    'pm10': 22.32,
#    'nh3': 1.24},
#   'dt': 1738040400},
#  {'main': {'aqi': 2},
#   'components': {'co': 453.95,
#    'no': 0.59,
#    'no2': 16.28,
#    'o3': 3.49,
#    'so2': 4.23,
#    'pm2_5': 10.87,
#    'pm10': 21.46,
#    'nh3': 1.35},
#   'dt': 1738044000},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 1.24,
#    'no2': 15.25,
#    'o3': 1.63,
#    'so2': 4.41,
#    'pm2_5': 11.08,
#    'pm10': 21.68,
#    'nh3': 1.41},
#   'dt': 1738047600},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 3.27,
#    'no2': 13.71,
#    'o3': 0.36,
#    'so2': 4.47,
#    'pm2_5': 10.98,
#    'pm10': 22.16,
#    'nh3': 1.41},
#   'dt': 1738051200},
#  {'main': {'aqi': 2},
#   'components': {'co': 494,
#    'no': 10.39,
#    'no2': 12.68,
#    'o3': 0.03,
#    'so2': 5.07,
#    'pm2_5': 11.56,
#    'pm10': 24.37,
#    'nh3': 1.66},
#   'dt': 1738054800},
#  {'main': {'aqi': 2},
#   'components': {'co': 647.54,
#    'no': 25.48,
#    'no2': 12.68,
#    'o3': 0.11,
#    'so2': 6.08,
#    'pm2_5': 13,
#    'pm10': 27.67,
#    'nh3': 1.95},
#   'dt': 1738058400},
#  {'main': {'aqi': 2},
#   'components': {'co': 707.63,
#    'no': 31.74,
#    'no2': 13.54,
#    'o3': 0.67,
#    'so2': 6.2,
#    'pm2_5': 12.03,
#    'pm10': 27.63,
#    'nh3': 1.79},
#   'dt': 1738062000},
#  {'main': {'aqi': 2},
#   'components': {'co': 574.11,
#    'no': 18.55,
#    'no2': 16.28,
#    'o3': 3.89,
#    'so2': 6.08,
#    'pm2_5': 8.37,
#    'pm10': 22.22,
#    'nh3': 2.09},
#   'dt': 1738065600},
#  {'main': {'aqi': 1},
#   'components': {'co': 377.18,
#    'no': 2.71,
#    'no2': 14.4,
#    'o3': 14.31,
#    'so2': 5.07,
#    'pm2_5': 3.94,
#    'pm10': 11.98,
#    'nh3': 2.12},
#   'dt': 1738069200},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 2.12,
#    'no2': 14.74,
#    'o3': 18.42,
#    'so2': 4.89,
#    'pm2_5': 4.24,
#    'pm10': 11.46,
#    'nh3': 1.96},
#   'dt': 1738072800},
#  {'main': {'aqi': 1},
#   'components': {'co': 420.57,
#    'no': 1.82,
#    'no2': 17.65,
#    'o3': 19.85,
#    'so2': 4.89,
#    'pm2_5': 5.41,
#    'pm10': 12.45,
#    'nh3': 1.85},
#   'dt': 1738076400},
#  {'main': {'aqi': 1},
#   'components': {'co': 453.95,
#    'no': 1.29,
#    'no2': 18.85,
#    'o3': 22.71,
#    'so2': 4.47,
#    'pm2_5': 6.8,
#    'pm10': 13.72,
#    'nh3': 1.76},
#   'dt': 1738080000},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.91,
#    'no2': 17.82,
#    'o3': 28.61,
#    'so2': 4.83,
#    'pm2_5': 7.4,
#    'pm10': 14.39,
#    'nh3': 2.03},
#   'dt': 1738083600},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.8,
#    'no2': 18.51,
#    'o3': 30.4,
#    'so2': 5.42,
#    'pm2_5': 7.26,
#    'pm10': 14.66,
#    'nh3': 2.44},
#   'dt': 1738087200},
#  {'main': {'aqi': 1},
#   'components': {'co': 540.73,
#    'no': 2.07,
#    'no2': 25.36,
#    'o3': 25.75,
#    'so2': 7.33,
#    'pm2_5': 8.64,
#    'pm10': 18.18,
#    'nh3': 3.1},
#   'dt': 1738090800},
#  {'main': {'aqi': 2},
#   'components': {'co': 674.25,
#    'no': 3.91,
#    'no2': 38.39,
#    'o3': 13.77,
#    'so2': 9.42,
#    'pm2_5': 11.42,
#    'pm10': 24.23,
#    'nh3': 3.39},
#   'dt': 1738094400},
#  {'main': {'aqi': 2},
#   'components': {'co': 761.03,
#    'no': 5.76,
#    'no2': 45.93,
#    'o3': 4.74,
#    'so2': 11.33,
#    'pm2_5': 13.96,
#    'pm10': 29.56,
#    'nh3': 3.45},
#   'dt': 1738098000},
#  {'main': {'aqi': 2},
#   'components': {'co': 814.44,
#    'no': 8.72,
#    'no2': 45.24,
#    'o3': 0.64,
#    'so2': 12.52,
#    'pm2_5': 16.72,
#    'pm10': 35.81,
#    'nh3': 3.61},
#   'dt': 1738101600},
#  {'main': {'aqi': 2},
#   'components': {'co': 821.11,
#    'no': 12.85,
#    'no2': 36.67,
#    'o3': 0.02,
#    'so2': 11.21,
#    'pm2_5': 18.25,
#    'pm10': 39.9,
#    'nh3': 2.98},
#   'dt': 1738105200},
#  {'main': {'aqi': 2},
#   'components': {'co': 781.06,
#    'no': 14.98,
#    'no2': 28.1,
#    'o3': 0.01,
#    'so2': 8.82,
#    'pm2_5': 17.96,
#    'pm10': 41.48,
#    'nh3': 2.34},
#   'dt': 1738108800},
#  {'main': {'aqi': 2},
#   'components': {'co': 720.98,
#    'no': 16.09,
#    'no2': 20.56,
#    'o3': 0.01,
#    'so2': 6.8,
#    'pm2_5': 16.2,
#    'pm10': 39.95,
#    'nh3': 1.87},
#   'dt': 1738112400},
#  {'main': {'aqi': 2},
#   'components': {'co': 654.22,
#    'no': 16.99,
#    'no2': 15.42,
#    'o3': 0,
#    'so2': 5.13,
#    'pm2_5': 13.85,
#    'pm10': 36.2,
#    'nh3': 1.47},
#   'dt': 1738116000},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 16.54,
#    'no2': 12,
#    'o3': 0,
#    'so2': 4.41,
#    'pm2_5': 12.48,
#    'pm10': 34.14,
#    'nh3': 1.38},
#   'dt': 1738119600},
#  {'main': {'aqi': 2},
#   'components': {'co': 534.06,
#    'no': 13.19,
#    'no2': 10.2,
#    'o3': 0,
#    'so2': 3.82,
#    'pm2_5': 11.52,
#    'pm10': 32.95,
#    'nh3': 1.28},
#   'dt': 1738123200},
#  {'main': {'aqi': 2},
#   'components': {'co': 473.98,
#    'no': 9.39,
#    'no2': 9.85,
#    'o3': 0.01,
#    'so2': 3.58,
#    'pm2_5': 10.64,
#    'pm10': 29.04,
#    'nh3': 1.24},
#   'dt': 1738126800},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 6.93,
#    'no2': 10.2,
#    'o3': 0.02,
#    'so2': 3.73,
#    'pm2_5': 10.19,
#    'pm10': 26.25,
#    'nh3': 1.3},
#   'dt': 1738130400},
#  {'main': {'aqi': 2},
#   'components': {'co': 413.9,
#    'no': 5.64,
#    'no2': 10.45,
#    'o3': 0.04,
#    'so2': 3.87,
#    'pm2_5': 9.88,
#    'pm10': 23.96,
#    'nh3': 1.33},
#   'dt': 1738134000},
#  {'main': {'aqi': 2},
#   'components': {'co': 400.54,
#    'no': 5.76,
#    'no2': 10.45,
#    'o3': 0.05,
#    'so2': 4.17,
#    'pm2_5': 9.39,
#    'pm10': 21.85,
#    'nh3': 1.38},
#   'dt': 1738137600},
#  {'main': {'aqi': 2},
#   'components': {'co': 427.25,
#    'no': 8.83,
#    'no2': 11.48,
#    'o3': 0.03,
#    'so2': 5.25,
#    'pm2_5': 8.67,
#    'pm10': 20.89,
#    'nh3': 1.82},
#   'dt': 1738141200},
#  {'main': {'aqi': 2},
#   'components': {'co': 453.95,
#    'no': 10.84,
#    'no2': 13.2,
#    'o3': 0.39,
#    'so2': 7.09,
#    'pm2_5': 6.88,
#    'pm10': 22.01,
#    'nh3': 2.69},
#   'dt': 1738144800},
#  {'main': {'aqi': 2},
#   'components': {'co': 480.65,
#    'no': 11.74,
#    'no2': 15.25,
#    'o3': 2.64,
#    'so2': 7.57,
#    'pm2_5': 6.09,
#    'pm10': 23.32,
#    'nh3': 2.85},
#   'dt': 1738148400},
#  {'main': {'aqi': 2},
#   'components': {'co': 467.3,
#    'no': 8.27,
#    'no2': 17.99,
#    'o3': 10.1,
#    'so2': 8.11,
#    'pm2_5': 5.49,
#    'pm10': 23.18,
#    'nh3': 3.55},
#   'dt': 1738152000},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 1.84,
#    'no2': 15.94,
#    'o3': 16.27,
#    'so2': 6.08,
#    'pm2_5': 3.37,
#    'pm10': 13.5,
#    'nh3': 2.82},
#   'dt': 1738155600},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 1.79,
#    'no2': 14.4,
#    'o3': 21.64,
#    'so2': 5.84,
#    'pm2_5': 3.62,
#    'pm10': 12.12,
#    'nh3': 2.47},
#   'dt': 1738159200},
#  {'main': {'aqi': 1},
#   'components': {'co': 400.54,
#    'no': 1.61,
#    'no2': 14.74,
#    'o3': 28.61,
#    'so2': 5.6,
#    'pm2_5': 4.21,
#    'pm10': 12.48,
#    'nh3': 2.22},
#   'dt': 1738162800},
#  {'main': {'aqi': 1},
#   'components': {'co': 413.9,
#    'no': 1.16,
#    'no2': 15.08,
#    'o3': 35.41,
#    'so2': 5.01,
#    'pm2_5': 4.78,
#    'pm10': 12.58,
#    'nh3': 1.93},
#   'dt': 1738166400},
#  {'main': {'aqi': 1},
#   'components': {'co': 427.25,
#    'no': 0.87,
#    'no2': 15.59,
#    'o3': 36.12,
#    'so2': 5.36,
#    'pm2_5': 5.27,
#    'pm10': 12.67,
#    'nh3': 2.06},
#   'dt': 1738170000},
#  {'main': {'aqi': 1},
#   'components': {'co': 440.6,
#    'no': 0.62,
#    'no2': 16.28,
#    'o3': 35.76,
#    'so2': 5.66,
#    'pm2_5': 5.58,
#    'pm10': 12.62,
#    'nh3': 2.22},
#   'dt': 1738173600},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.63,
#    'no2': 18.68,
#    'o3': 32.9,
#    'so2': 5.9,
#    'pm2_5': 5.81,
#    'pm10': 12.97,
#    'nh3': 2.41},
#   'dt': 1738177200},
#  {'main': {'aqi': 1},
#   'components': {'co': 534.06,
#    'no': 0.71,
#    'no2': 26.39,
#    'o3': 26.11,
#    'so2': 7.75,
#    'pm2_5': 7.09,
#    'pm10': 16.29,
#    'nh3': 3.1},
#   'dt': 1738180800},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 0.38,
#    'no2': 33.59,
#    'o3': 21.28,
#    'so2': 10.01,
#    'pm2_5': 9.17,
#    'pm10': 20.7,
#    'nh3': 3.86},
#   'dt': 1738184400},
#  {'main': {'aqi': 2},
#   'components': {'co': 667.57,
#    'no': 0.36,
#    'no2': 41.13,
#    'o3': 13.05,
#    'so2': 12.64,
#    'pm2_5': 12.8,
#    'pm10': 27.47,
#    'nh3': 4.37},
#   'dt': 1738188000},
#  {'main': {'aqi': 2},
#   'components': {'co': 707.63,
#    'no': 1.34,
#    'no2': 42.5,
#    'o3': 3.89,
#    'so2': 12.52,
#    'pm2_5': 15.49,
#    'pm10': 32.96,
#    'nh3': 3.64},
#   'dt': 1738191600},
#  {'main': {'aqi': 2},
#   'components': {'co': 687.6,
#    'no': 3.05,
#    'no2': 35.64,
#    'o3': 0.95,
#    'so2': 10.13,
#    'pm2_5': 15.38,
#    'pm10': 33.78,
#    'nh3': 2.76},
#   'dt': 1738195200}]

# %%
print(data.keys)
# Out:
# <built-in method keys of dict object at 0x00000214FF9F0480>

# %%
for item in data['list']:
    print(item)
# Out:
# {'main': {'aqi': 2}, 'components': {'co': 680.92, 'no': 0.67, 'no2': 20.56, 'o3': 4.16, 'so2': 4.65, 'pm2_5': 24.18, 'pm10': 40.95, 'nh3': 1.92}, 'dt': 1737864000}
# {'main': {'aqi': 2}, 'components': {'co': 634.19, 'no': 0.63, 'no2': 21.42, 'o3': 3.89, 'so2': 6.44, 'pm2_5': 23, 'pm10': 40.23, 'nh3': 3.17}, 'dt': 1737867600}
# {'main': {'aqi': 2}, 'components': {'co': 634.19, 'no': 1.09, 'no2': 23.99, 'o3': 2.19, 'so2': 8.7, 'pm2_5': 23.64, 'pm10': 40.64, 'nh3': 4.5}, 'dt': 1737871200}
# {'main': {'aqi': 3}, 'components': {'co': 674.25, 'no': 2.65, 'no2': 27.08, 'o3': 0.57, 'so2': 11.44, 'pm2_5': 27.29, 'pm10': 44.53, 'nh3': 5.83}, 'dt': 1737874800}
# {'main': {'aqi': 3}, 'components': {'co': 741.01, 'no': 6.04, 'no2': 29.82, 'o3': 0.07, 'so2': 14.07, 'pm2_5': 32.34, 'pm10': 50.52, 'nh3': 7.09}, 'dt': 1737878400}
# {'main': {'aqi': 3}, 'components': {'co': 881.2, 'no': 16.54, 'no2': 31.53, 'o3': 0, 'so2': 16.69, 'pm2_5': 39.58, 'pm10': 59.87, 'nh3': 8.36}, 'dt': 1737882000}
# {'main': {'aqi': 3}, 'components': {'co': 1201.63, 'no': 41.13, 'no2': 28.45, 'o3': 0.18, 'so2': 15.14, 'pm2_5': 49.36, 'pm10': 71.29, 'nh3': 6.27}, 'dt': 1737885600}
# {'main': {'aqi': 4}, 'components': {'co': 1508.71, 'no': 61.69, 'no2': 27.76, 'o3': 1.74, 'so2': 11.92, 'pm2_5': 55.94, 'pm10': 81.63, 'nh3': 3.52}, 'dt': 1737889200}
# {'main': {'aqi': 4}, 'components': {'co': 1575.47, 'no': 48.28, 'no2': 45.93, 'o3': 12.7, 'so2': 10.49, 'pm2_5': 62.75, 'pm10': 91.94, 'nh3': 2.85}, 'dt': 1737892800}
# {'main': {'aqi': 3}, 'components': {'co': 714.3, 'no': 2.04, 'no2': 20.91, 'o3': 121.59, 'so2': 14.78, 'pm2_5': 34.72, 'pm10': 55.95, 'nh3': 7.54}, 'dt': 1737896400}
# {'main': {'aqi': 3}, 'components': {'co': 554.09, 'no': 0.52, 'no2': 9.68, 'o3': 130.18, 'so2': 9.06, 'pm2_5': 20.83, 'pm10': 35.41, 'nh3': 4.94}, 'dt': 1737900000}
# {'main': {'aqi': 3}, 'components': {'co': 514.03, 'no': 0.16, 'no2': 8.65, 'o3': 118.73, 'so2': 7.45, 'pm2_5': 16.76, 'pm10': 29.59, 'nh3': 3.9}, 'dt': 1737903600}
# {'main': {'aqi': 2}, 'components': {'co': 473.98, 'no': 0, 'no2': 8.4, 'o3': 95.84, 'so2': 5.66, 'pm2_5': 12.52, 'pm10': 23.02, 'nh3': 2.91}, 'dt': 1737907200}
# {'main': {'aqi': 2}, 'components': {'co': 507.36, 'no': 0, 'no2': 11.82, 'o3': 81.54, 'so2': 6.91, 'pm2_5': 13.03, 'pm10': 23.66, 'nh3': 3.58}, 'dt': 1737910800}
# {'main': {'aqi': 2}, 'components': {'co': 660.9, 'no': 0.01, 'no2': 21.94, 'o3': 72.24, 'so2': 12.76, 'pm2_5': 19.89, 'pm10': 33.94, 'nh3': 6.08}, 'dt': 1737914400}
# {'main': {'aqi': 3}, 'components': {'co': 1001.36, 'no': 0.02, 'no2': 46.61, 'o3': 53.64, 'so2': 24.56, 'pm2_5': 36.32, 'pm10': 57.01, 'nh3': 9.63}, 'dt': 1737918000}
# {'main': {'aqi': 4}, 'components': {'co': 1415.25, 'no': 0.05, 'no2': 80.2, 'o3': 23.25, 'so2': 34.81, 'pm2_5': 55.63, 'pm10': 81.81, 'nh3': 10.26}, 'dt': 1737921600}
# {'main': {'aqi': 4}, 'components': {'co': 1695.63, 'no': 1.96, 'no2': 105.56, 'o3': 3.71, 'so2': 39.58, 'pm2_5': 66.88, 'pm10': 93.61, 'nh3': 8.99}, 'dt': 1737925200}
# {'main': {'aqi': 4}, 'components': {'co': 1762.39, 'no': 7.82, 'no2': 111.04, 'o3': 0.06, 'so2': 38.15, 'pm2_5': 64.87, 'pm10': 88.35, 'nh3': 8.36}, 'dt': 1737928800}
# {'main': {'aqi': 4}, 'components': {'co': 1602.17, 'no': 11.06, 'no2': 98.71, 'o3': 0, 'so2': 33.38, 'pm2_5': 52.88, 'pm10': 72.11, 'nh3': 7.54}, 'dt': 1737932400}
# {'main': {'aqi': 3}, 'components': {'co': 1415.25, 'no': 11.51, 'no2': 85, 'o3': 0, 'so2': 29.09, 'pm2_5': 42.62, 'pm10': 59, 'nh3': 6.65}, 'dt': 1737936000}
# {'main': {'aqi': 3}, 'components': {'co': 1255.04, 'no': 10.39, 'no2': 70.6, 'o3': 0.01, 'so2': 23.6, 'pm2_5': 37.55, 'pm10': 52.72, 'nh3': 5.19}, 'dt': 1737939600}
# {'main': {'aqi': 3}, 'components': {'co': 1134.87, 'no': 9.16, 'no2': 57.58, 'o3': 0.02, 'so2': 18.84, 'pm2_5': 35.85, 'pm10': 49.59, 'nh3': 4.05}, 'dt': 1737943200}
# {'main': {'aqi': 3}, 'components': {'co': 1081.47, 'no': 8.72, 'no2': 51.41, 'o3': 0.03, 'so2': 16.93, 'pm2_5': 34.99, 'pm10': 49.09, 'nh3': 4.02}, 'dt': 1737946800}
# {'main': {'aqi': 3}, 'components': {'co': 1081.47, 'no': 10.51, 'no2': 45.93, 'o3': 0.01, 'so2': 14.78, 'pm2_5': 37.14, 'pm10': 52.79, 'nh3': 3.36}, 'dt': 1737950400}
# {'main': {'aqi': 3}, 'components': {'co': 1094.82, 'no': 13.75, 'no2': 39.41, 'o3': 0, 'so2': 12.4, 'pm2_5': 40.92, 'pm10': 57.97, 'nh3': 2.88}, 'dt': 1737954000}
# {'main': {'aqi': 3}, 'components': {'co': 1108.17, 'no': 16.99, 'no2': 34.96, 'o3': 0, 'so2': 12.04, 'pm2_5': 44.87, 'pm10': 63.55, 'nh3': 3.14}, 'dt': 1737957600}
# {'main': {'aqi': 4}, 'components': {'co': 1161.58, 'no': 22.13, 'no2': 33.59, 'o3': 0, 'so2': 13.11, 'pm2_5': 50.81, 'pm10': 71.11, 'nh3': 3.93}, 'dt': 1737961200}
# {'main': {'aqi': 4}, 'components': {'co': 1241.68, 'no': 29.5, 'no2': 33.24, 'o3': 0, 'so2': 14.19, 'pm2_5': 57.62, 'pm10': 79.07, 'nh3': 4.5}, 'dt': 1737964800}
# {'main': {'aqi': 4}, 'components': {'co': 1388.55, 'no': 43.81, 'no2': 32.56, 'o3': 0, 'so2': 15.26, 'pm2_5': 65.33, 'pm10': 88.36, 'nh3': 5.19}, 'dt': 1737968400}
# {'main': {'aqi': 4}, 'components': {'co': 1642.23, 'no': 67.95, 'no2': 32.22, 'o3': 0, 'so2': 16.45, 'pm2_5': 70.67, 'pm10': 94.57, 'nh3': 5.45}, 'dt': 1737972000}
# {'main': {'aqi': 4}, 'components': {'co': 1682.28, 'no': 77.78, 'no2': 28.1, 'o3': 0.01, 'so2': 14.19, 'pm2_5': 66.35, 'pm10': 90.87, 'nh3': 4.12}, 'dt': 1737975600}
# {'main': {'aqi': 4}, 'components': {'co': 1428.6, 'no': 62.59, 'no2': 25.36, 'o3': 0.04, 'so2': 11.92, 'pm2_5': 53.07, 'pm10': 78.49, 'nh3': 3.39}, 'dt': 1737979200}
# {'main': {'aqi': 2}, 'components': {'co': 734.33, 'no': 14.75, 'no2': 29.13, 'o3': 3.98, 'so2': 11.33, 'pm2_5': 20.91, 'pm10': 42.57, 'nh3': 4.56}, 'dt': 1737982800}
# {'main': {'aqi': 2}, 'components': {'co': 560.76, 'no': 4.19, 'no2': 28.45, 'o3': 10.82, 'so2': 9.54, 'pm2_5': 11.99, 'pm10': 29.92, 'nh3': 4.12}, 'dt': 1737986400}
# {'main': {'aqi': 2}, 'components': {'co': 500.68, 'no': 1.76, 'no2': 26.73, 'o3': 19.31, 'so2': 8.7, 'pm2_5': 8.94, 'pm10': 24.31, 'nh3': 4.12}, 'dt': 1737990000}
# {'main': {'aqi': 1}, 'components': {'co': 423.91, 'no': 0.44, 'no2': 16.11, 'o3': 35.05, 'so2': 4.95, 'pm2_5': 5.35, 'pm10': 13.61, 'nh3': 2.38}, 'dt': 1737993600}
# {'main': {'aqi': 1}, 'components': {'co': 433.92, 'no': 0.19, 'no2': 16.11, 'o3': 37.91, 'so2': 5.01, 'pm2_5': 5.23, 'pm10': 12.28, 'nh3': 2.38}, 'dt': 1737997200}
# {'main': {'aqi': 1}, 'components': {'co': 467.3, 'no': 0.12, 'no2': 19.36, 'o3': 35.05, 'so2': 6.32, 'pm2_5': 6.04, 'pm10': 13.6, 'nh3': 2.91}, 'dt': 1738000800}
# {'main': {'aqi': 1}, 'components': {'co': 514.03, 'no': 0.11, 'no2': 24.68, 'o3': 29.33, 'so2': 7.87, 'pm2_5': 6.99, 'pm10': 15.83, 'nh3': 3.42}, 'dt': 1738004400}
# {'main': {'aqi': 1}, 'components': {'co': 567.44, 'no': 0.18, 'no2': 30.85, 'o3': 22.89, 'so2': 9.54, 'pm2_5': 8.01, 'pm10': 18.48, 'nh3': 3.67}, 'dt': 1738008000}
# {'main': {'aqi': 2}, 'components': {'co': 594.14, 'no': 0.31, 'no2': 34.62, 'o3': 19.13, 'so2': 10.97, 'pm2_5': 8.95, 'pm10': 20.82, 'nh3': 3.67}, 'dt': 1738011600}
# {'main': {'aqi': 2}, 'components': {'co': 674.25, 'no': 1.17, 'no2': 41.13, 'o3': 8.67, 'so2': 12.4, 'pm2_5': 12.35, 'pm10': 26.32, 'nh3': 3.39}, 'dt': 1738015200}
# {'main': {'aqi': 2}, 'components': {'co': 794.41, 'no': 5.81, 'no2': 42.84, 'o3': 0.53, 'so2': 12.88, 'pm2_5': 17.61, 'pm10': 33.21, 'nh3': 3.07}, 'dt': 1738018800}
# {'main': {'aqi': 2}, 'components': {'co': 921.25, 'no': 14.31, 'no2': 39.76, 'o3': 0.01, 'so2': 13.35, 'pm2_5': 23.3, 'pm10': 39.61, 'nh3': 3.2}, 'dt': 1738022400}
# {'main': {'aqi': 3}, 'components': {'co': 1028.06, 'no': 22.58, 'no2': 37.01, 'o3': 0, 'so2': 14.07, 'pm2_5': 28.96, 'pm10': 45.96, 'nh3': 3.74}, 'dt': 1738026000}
# {'main': {'aqi': 3}, 'components': {'co': 961.3, 'no': 21.68, 'no2': 32.22, 'o3': 0, 'so2': 11.56, 'pm2_5': 27.96, 'pm10': 44.5, 'nh3': 3.14}, 'dt': 1738029600}
# {'main': {'aqi': 2}, 'components': {'co': 767.71, 'no': 13.3, 'no2': 26.73, 'o3': 0.02, 'so2': 7.87, 'pm2_5': 21.47, 'pm10': 36.61, 'nh3': 2.09}, 'dt': 1738033200}
# {'main': {'aqi': 2}, 'components': {'co': 574.11, 'no': 3.58, 'no2': 21.94, 'o3': 0.85, 'so2': 4.89, 'pm2_5': 14.01, 'pm10': 26.7, 'nh3': 1.36}, 'dt': 1738036800}
# {'main': {'aqi': 2}, 'components': {'co': 480.65, 'no': 0.7, 'no2': 17.99, 'o3': 3.26, 'so2': 4.05, 'pm2_5': 11.03, 'pm10': 22.32, 'nh3': 1.24}, 'dt': 1738040400}
# {'main': {'aqi': 2}, 'components': {'co': 453.95, 'no': 0.59, 'no2': 16.28, 'o3': 3.49, 'so2': 4.23, 'pm2_5': 10.87, 'pm10': 21.46, 'nh3': 1.35}, 'dt': 1738044000}
# {'main': {'aqi': 2}, 'components': {'co': 440.6, 'no': 1.24, 'no2': 15.25, 'o3': 1.63, 'so2': 4.41, 'pm2_5': 11.08, 'pm10': 21.68, 'nh3': 1.41}, 'dt': 1738047600}
# {'main': {'aqi': 2}, 'components': {'co': 440.6, 'no': 3.27, 'no2': 13.71, 'o3': 0.36, 'so2': 4.47, 'pm2_5': 10.98, 'pm10': 22.16, 'nh3': 1.41}, 'dt': 1738051200}
# {'main': {'aqi': 2}, 'components': {'co': 494, 'no': 10.39, 'no2': 12.68, 'o3': 0.03, 'so2': 5.07, 'pm2_5': 11.56, 'pm10': 24.37, 'nh3': 1.66}, 'dt': 1738054800}
# {'main': {'aqi': 2}, 'components': {'co': 647.54, 'no': 25.48, 'no2': 12.68, 'o3': 0.11, 'so2': 6.08, 'pm2_5': 13, 'pm10': 27.67, 'nh3': 1.95}, 'dt': 1738058400}
# {'main': {'aqi': 2}, 'components': {'co': 707.63, 'no': 31.74, 'no2': 13.54, 'o3': 0.67, 'so2': 6.2, 'pm2_5': 12.03, 'pm10': 27.63, 'nh3': 1.79}, 'dt': 1738062000}
# {'main': {'aqi': 2}, 'components': {'co': 574.11, 'no': 18.55, 'no2': 16.28, 'o3': 3.89, 'so2': 6.08, 'pm2_5': 8.37, 'pm10': 22.22, 'nh3': 2.09}, 'dt': 1738065600}
# {'main': {'aqi': 1}, 'components': {'co': 377.18, 'no': 2.71, 'no2': 14.4, 'o3': 14.31, 'so2': 5.07, 'pm2_5': 3.94, 'pm10': 11.98, 'nh3': 2.12}, 'dt': 1738069200}
# {'main': {'aqi': 1}, 'components': {'co': 383.85, 'no': 2.12, 'no2': 14.74, 'o3': 18.42, 'so2': 4.89, 'pm2_5': 4.24, 'pm10': 11.46, 'nh3': 1.96}, 'dt': 1738072800}
# {'main': {'aqi': 1}, 'components': {'co': 420.57, 'no': 1.82, 'no2': 17.65, 'o3': 19.85, 'so2': 4.89, 'pm2_5': 5.41, 'pm10': 12.45, 'nh3': 1.85}, 'dt': 1738076400}
# {'main': {'aqi': 1}, 'components': {'co': 453.95, 'no': 1.29, 'no2': 18.85, 'o3': 22.71, 'so2': 4.47, 'pm2_5': 6.8, 'pm10': 13.72, 'nh3': 1.76}, 'dt': 1738080000}
# {'main': {'aqi': 1}, 'components': {'co': 467.3, 'no': 0.91, 'no2': 17.82, 'o3': 28.61, 'so2': 4.83, 'pm2_5': 7.4, 'pm10': 14.39, 'nh3': 2.03}, 'dt': 1738083600}
# {'main': {'aqi': 1}, 'components': {'co': 467.3, 'no': 0.8, 'no2': 18.51, 'o3': 30.4, 'so2': 5.42, 'pm2_5': 7.26, 'pm10': 14.66, 'nh3': 2.44}, 'dt': 1738087200}
# {'main': {'aqi': 1}, 'components': {'co': 540.73, 'no': 2.07, 'no2': 25.36, 'o3': 25.75, 'so2': 7.33, 'pm2_5': 8.64, 'pm10': 18.18, 'nh3': 3.1}, 'dt': 1738090800}
# {'main': {'aqi': 2}, 'components': {'co': 674.25, 'no': 3.91, 'no2': 38.39, 'o3': 13.77, 'so2': 9.42, 'pm2_5': 11.42, 'pm10': 24.23, 'nh3': 3.39}, 'dt': 1738094400}
# {'main': {'aqi': 2}, 'components': {'co': 761.03, 'no': 5.76, 'no2': 45.93, 'o3': 4.74, 'so2': 11.33, 'pm2_5': 13.96, 'pm10': 29.56, 'nh3': 3.45}, 'dt': 1738098000}
# {'main': {'aqi': 2}, 'components': {'co': 814.44, 'no': 8.72, 'no2': 45.24, 'o3': 0.64, 'so2': 12.52, 'pm2_5': 16.72, 'pm10': 35.81, 'nh3': 3.61}, 'dt': 1738101600}
# {'main': {'aqi': 2}, 'components': {'co': 821.11, 'no': 12.85, 'no2': 36.67, 'o3': 0.02, 'so2': 11.21, 'pm2_5': 18.25, 'pm10': 39.9, 'nh3': 2.98}, 'dt': 1738105200}
# {'main': {'aqi': 2}, 'components': {'co': 781.06, 'no': 14.98, 'no2': 28.1, 'o3': 0.01, 'so2': 8.82, 'pm2_5': 17.96, 'pm10': 41.48, 'nh3': 2.34}, 'dt': 1738108800}
# {'main': {'aqi': 2}, 'components': {'co': 720.98, 'no': 16.09, 'no2': 20.56, 'o3': 0.01, 'so2': 6.8, 'pm2_5': 16.2, 'pm10': 39.95, 'nh3': 1.87}, 'dt': 1738112400}
# {'main': {'aqi': 2}, 'components': {'co': 654.22, 'no': 16.99, 'no2': 15.42, 'o3': 0, 'so2': 5.13, 'pm2_5': 13.85, 'pm10': 36.2, 'nh3': 1.47}, 'dt': 1738116000}
# {'main': {'aqi': 2}, 'components': {'co': 594.14, 'no': 16.54, 'no2': 12, 'o3': 0, 'so2': 4.41, 'pm2_5': 12.48, 'pm10': 34.14, 'nh3': 1.38}, 'dt': 1738119600}
# {'main': {'aqi': 2}, 'components': {'co': 534.06, 'no': 13.19, 'no2': 10.2, 'o3': 0, 'so2': 3.82, 'pm2_5': 11.52, 'pm10': 32.95, 'nh3': 1.28}, 'dt': 1738123200}
# {'main': {'aqi': 2}, 'components': {'co': 473.98, 'no': 9.39, 'no2': 9.85, 'o3': 0.01, 'so2': 3.58, 'pm2_5': 10.64, 'pm10': 29.04, 'nh3': 1.24}, 'dt': 1738126800}
# {'main': {'aqi': 2}, 'components': {'co': 440.6, 'no': 6.93, 'no2': 10.2, 'o3': 0.02, 'so2': 3.73, 'pm2_5': 10.19, 'pm10': 26.25, 'nh3': 1.3}, 'dt': 1738130400}
# {'main': {'aqi': 2}, 'components': {'co': 413.9, 'no': 5.64, 'no2': 10.45, 'o3': 0.04, 'so2': 3.87, 'pm2_5': 9.88, 'pm10': 23.96, 'nh3': 1.33}, 'dt': 1738134000}
# {'main': {'aqi': 2}, 'components': {'co': 400.54, 'no': 5.76, 'no2': 10.45, 'o3': 0.05, 'so2': 4.17, 'pm2_5': 9.39, 'pm10': 21.85, 'nh3': 1.38}, 'dt': 1738137600}
# {'main': {'aqi': 2}, 'components': {'co': 427.25, 'no': 8.83, 'no2': 11.48, 'o3': 0.03, 'so2': 5.25, 'pm2_5': 8.67, 'pm10': 20.89, 'nh3': 1.82}, 'dt': 1738141200}
# {'main': {'aqi': 2}, 'components': {'co': 453.95, 'no': 10.84, 'no2': 13.2, 'o3': 0.39, 'so2': 7.09, 'pm2_5': 6.88, 'pm10': 22.01, 'nh3': 2.69}, 'dt': 1738144800}
# {'main': {'aqi': 2}, 'components': {'co': 480.65, 'no': 11.74, 'no2': 15.25, 'o3': 2.64, 'so2': 7.57, 'pm2_5': 6.09, 'pm10': 23.32, 'nh3': 2.85}, 'dt': 1738148400}
# {'main': {'aqi': 2}, 'components': {'co': 467.3, 'no': 8.27, 'no2': 17.99, 'o3': 10.1, 'so2': 8.11, 'pm2_5': 5.49, 'pm10': 23.18, 'nh3': 3.55}, 'dt': 1738152000}
# {'main': {'aqi': 1}, 'components': {'co': 383.85, 'no': 1.84, 'no2': 15.94, 'o3': 16.27, 'so2': 6.08, 'pm2_5': 3.37, 'pm10': 13.5, 'nh3': 2.82}, 'dt': 1738155600}
# {'main': {'aqi': 1}, 'components': {'co': 383.85, 'no': 1.79, 'no2': 14.4, 'o3': 21.64, 'so2': 5.84, 'pm2_5': 3.62, 'pm10': 12.12, 'nh3': 2.47}, 'dt': 1738159200}
# {'main': {'aqi': 1}, 'components': {'co': 400.54, 'no': 1.61, 'no2': 14.74, 'o3': 28.61, 'so2': 5.6, 'pm2_5': 4.21, 'pm10': 12.48, 'nh3': 2.22}, 'dt': 1738162800}
# {'main': {'aqi': 1}, 'components': {'co': 413.9, 'no': 1.16, 'no2': 15.08, 'o3': 35.41, 'so2': 5.01, 'pm2_5': 4.78, 'pm10': 12.58, 'nh3': 1.93}, 'dt': 1738166400}
# {'main': {'aqi': 1}, 'components': {'co': 427.25, 'no': 0.87, 'no2': 15.59, 'o3': 36.12, 'so2': 5.36, 'pm2_5': 5.27, 'pm10': 12.67, 'nh3': 2.06}, 'dt': 1738170000}
# {'main': {'aqi': 1}, 'components': {'co': 440.6, 'no': 0.62, 'no2': 16.28, 'o3': 35.76, 'so2': 5.66, 'pm2_5': 5.58, 'pm10': 12.62, 'nh3': 2.22}, 'dt': 1738173600}
# {'main': {'aqi': 1}, 'components': {'co': 467.3, 'no': 0.63, 'no2': 18.68, 'o3': 32.9, 'so2': 5.9, 'pm2_5': 5.81, 'pm10': 12.97, 'nh3': 2.41}, 'dt': 1738177200}
# {'main': {'aqi': 1}, 'components': {'co': 534.06, 'no': 0.71, 'no2': 26.39, 'o3': 26.11, 'so2': 7.75, 'pm2_5': 7.09, 'pm10': 16.29, 'nh3': 3.1}, 'dt': 1738180800}
# {'main': {'aqi': 2}, 'components': {'co': 594.14, 'no': 0.38, 'no2': 33.59, 'o3': 21.28, 'so2': 10.01, 'pm2_5': 9.17, 'pm10': 20.7, 'nh3': 3.86}, 'dt': 1738184400}
# {'main': {'aqi': 2}, 'components': {'co': 667.57, 'no': 0.36, 'no2': 41.13, 'o3': 13.05, 'so2': 12.64, 'pm2_5': 12.8, 'pm10': 27.47, 'nh3': 4.37}, 'dt': 1738188000}
# {'main': {'aqi': 2}, 'components': {'co': 707.63, 'no': 1.34, 'no2': 42.5, 'o3': 3.89, 'so2': 12.52, 'pm2_5': 15.49, 'pm10': 32.96, 'nh3': 3.64}, 'dt': 1738191600}
# {'main': {'aqi': 2}, 'components': {'co': 687.6, 'no': 3.05, 'no2': 35.64, 'o3': 0.95, 'so2': 10.13, 'pm2_5': 15.38, 'pm10': 33.78, 'nh3': 2.76}, 'dt': 1738195200}

# %%
data['list']
# Out:
# [{'main': {'aqi': 2},
#   'components': {'co': 680.92,
#    'no': 0.67,
#    'no2': 20.56,
#    'o3': 4.16,
#    'so2': 4.65,
#    'pm2_5': 24.18,
#    'pm10': 40.95,
#    'nh3': 1.92},
#   'dt': 1737864000},
#  {'main': {'aqi': 2},
#   'components': {'co': 634.19,
#    'no': 0.63,
#    'no2': 21.42,
#    'o3': 3.89,
#    'so2': 6.44,
#    'pm2_5': 23,
#    'pm10': 40.23,
#    'nh3': 3.17},
#   'dt': 1737867600},
#  {'main': {'aqi': 2},
#   'components': {'co': 634.19,
#    'no': 1.09,
#    'no2': 23.99,
#    'o3': 2.19,
#    'so2': 8.7,
#    'pm2_5': 23.64,
#    'pm10': 40.64,
#    'nh3': 4.5},
#   'dt': 1737871200},
#  {'main': {'aqi': 3},
#   'components': {'co': 674.25,
#    'no': 2.65,
#    'no2': 27.08,
#    'o3': 0.57,
#    'so2': 11.44,
#    'pm2_5': 27.29,
#    'pm10': 44.53,
#    'nh3': 5.83},
#   'dt': 1737874800},
#  {'main': {'aqi': 3},
#   'components': {'co': 741.01,
#    'no': 6.04,
#    'no2': 29.82,
#    'o3': 0.07,
#    'so2': 14.07,
#    'pm2_5': 32.34,
#    'pm10': 50.52,
#    'nh3': 7.09},
#   'dt': 1737878400},
#  {'main': {'aqi': 3},
#   'components': {'co': 881.2,
#    'no': 16.54,
#    'no2': 31.53,
#    'o3': 0,
#    'so2': 16.69,
#    'pm2_5': 39.58,
#    'pm10': 59.87,
#    'nh3': 8.36},
#   'dt': 1737882000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1201.63,
#    'no': 41.13,
#    'no2': 28.45,
#    'o3': 0.18,
#    'so2': 15.14,
#    'pm2_5': 49.36,
#    'pm10': 71.29,
#    'nh3': 6.27},
#   'dt': 1737885600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1508.71,
#    'no': 61.69,
#    'no2': 27.76,
#    'o3': 1.74,
#    'so2': 11.92,
#    'pm2_5': 55.94,
#    'pm10': 81.63,
#    'nh3': 3.52},
#   'dt': 1737889200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1575.47,
#    'no': 48.28,
#    'no2': 45.93,
#    'o3': 12.7,
#    'so2': 10.49,
#    'pm2_5': 62.75,
#    'pm10': 91.94,
#    'nh3': 2.85},
#   'dt': 1737892800},
#  {'main': {'aqi': 3},
#   'components': {'co': 714.3,
#    'no': 2.04,
#    'no2': 20.91,
#    'o3': 121.59,
#    'so2': 14.78,
#    'pm2_5': 34.72,
#    'pm10': 55.95,
#    'nh3': 7.54},
#   'dt': 1737896400},
#  {'main': {'aqi': 3},
#   'components': {'co': 554.09,
#    'no': 0.52,
#    'no2': 9.68,
#    'o3': 130.18,
#    'so2': 9.06,
#    'pm2_5': 20.83,
#    'pm10': 35.41,
#    'nh3': 4.94},
#   'dt': 1737900000},
#  {'main': {'aqi': 3},
#   'components': {'co': 514.03,
#    'no': 0.16,
#    'no2': 8.65,
#    'o3': 118.73,
#    'so2': 7.45,
#    'pm2_5': 16.76,
#    'pm10': 29.59,
#    'nh3': 3.9},
#   'dt': 1737903600},
#  {'main': {'aqi': 2},
#   'components': {'co': 473.98,
#    'no': 0,
#    'no2': 8.4,
#    'o3': 95.84,
#    'so2': 5.66,
#    'pm2_5': 12.52,
#    'pm10': 23.02,
#    'nh3': 2.91},
#   'dt': 1737907200},
#  {'main': {'aqi': 2},
#   'components': {'co': 507.36,
#    'no': 0,
#    'no2': 11.82,
#    'o3': 81.54,
#    'so2': 6.91,
#    'pm2_5': 13.03,
#    'pm10': 23.66,
#    'nh3': 3.58},
#   'dt': 1737910800},
#  {'main': {'aqi': 2},
#   'components': {'co': 660.9,
#    'no': 0.01,
#    'no2': 21.94,
#    'o3': 72.24,
#    'so2': 12.76,
#    'pm2_5': 19.89,
#    'pm10': 33.94,
#    'nh3': 6.08},
#   'dt': 1737914400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1001.36,
#    'no': 0.02,
#    'no2': 46.61,
#    'o3': 53.64,
#    'so2': 24.56,
#    'pm2_5': 36.32,
#    'pm10': 57.01,
#    'nh3': 9.63},
#   'dt': 1737918000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1415.25,
#    'no': 0.05,
#    'no2': 80.2,
#    'o3': 23.25,
#    'so2': 34.81,
#    'pm2_5': 55.63,
#    'pm10': 81.81,
#    'nh3': 10.26},
#   'dt': 1737921600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1695.63,
#    'no': 1.96,
#    'no2': 105.56,
#    'o3': 3.71,
#    'so2': 39.58,
#    'pm2_5': 66.88,
#    'pm10': 93.61,
#    'nh3': 8.99},
#   'dt': 1737925200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1762.39,
#    'no': 7.82,
#    'no2': 111.04,
#    'o3': 0.06,
#    'so2': 38.15,
#    'pm2_5': 64.87,
#    'pm10': 88.35,
#    'nh3': 8.36},
#   'dt': 1737928800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1602.17,
#    'no': 11.06,
#    'no2': 98.71,
#    'o3': 0,
#    'so2': 33.38,
#    'pm2_5': 52.88,
#    'pm10': 72.11,
#    'nh3': 7.54},
#   'dt': 1737932400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1415.25,
#    'no': 11.51,
#    'no2': 85,
#    'o3': 0,
#    'so2': 29.09,
#    'pm2_5': 42.62,
#    'pm10': 59,
#    'nh3': 6.65},
#   'dt': 1737936000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1255.04,
#    'no': 10.39,
#    'no2': 70.6,
#    'o3': 0.01,
#    'so2': 23.6,
#    'pm2_5': 37.55,
#    'pm10': 52.72,
#    'nh3': 5.19},
#   'dt': 1737939600},
#  {'main': {'aqi': 3},
#   'components': {'co': 1134.87,
#    'no': 9.16,
#    'no2': 57.58,
#    'o3': 0.02,
#    'so2': 18.84,
#    'pm2_5': 35.85,
#    'pm10': 49.59,
#    'nh3': 4.05},
#   'dt': 1737943200},
#  {'main': {'aqi': 3},
#   'components': {'co': 1081.47,
#    'no': 8.72,
#    'no2': 51.41,
#    'o3': 0.03,
#    'so2': 16.93,
#    'pm2_5': 34.99,
#    'pm10': 49.09,
#    'nh3': 4.02},
#   'dt': 1737946800},
#  {'main': {'aqi': 3},
#   'components': {'co': 1081.47,
#    'no': 10.51,
#    'no2': 45.93,
#    'o3': 0.01,
#    'so2': 14.78,
#    'pm2_5': 37.14,
#    'pm10': 52.79,
#    'nh3': 3.36},
#   'dt': 1737950400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1094.82,
#    'no': 13.75,
#    'no2': 39.41,
#    'o3': 0,
#    'so2': 12.4,
#    'pm2_5': 40.92,
#    'pm10': 57.97,
#    'nh3': 2.88},
#   'dt': 1737954000},
#  {'main': {'aqi': 3},
#   'components': {'co': 1108.17,
#    'no': 16.99,
#    'no2': 34.96,
#    'o3': 0,
#    'so2': 12.04,
#    'pm2_5': 44.87,
#    'pm10': 63.55,
#    'nh3': 3.14},
#   'dt': 1737957600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1161.58,
#    'no': 22.13,
#    'no2': 33.59,
#    'o3': 0,
#    'so2': 13.11,
#    'pm2_5': 50.81,
#    'pm10': 71.11,
#    'nh3': 3.93},
#   'dt': 1737961200},
#  {'main': {'aqi': 4},
#   'components': {'co': 1241.68,
#    'no': 29.5,
#    'no2': 33.24,
#    'o3': 0,
#    'so2': 14.19,
#    'pm2_5': 57.62,
#    'pm10': 79.07,
#    'nh3': 4.5},
#   'dt': 1737964800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1388.55,
#    'no': 43.81,
#    'no2': 32.56,
#    'o3': 0,
#    'so2': 15.26,
#    'pm2_5': 65.33,
#    'pm10': 88.36,
#    'nh3': 5.19},
#   'dt': 1737968400},
#  {'main': {'aqi': 4},
#   'components': {'co': 1642.23,
#    'no': 67.95,
#    'no2': 32.22,
#    'o3': 0,
#    'so2': 16.45,
#    'pm2_5': 70.67,
#    'pm10': 94.57,
#    'nh3': 5.45},
#   'dt': 1737972000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1682.28,
#    'no': 77.78,
#    'no2': 28.1,
#    'o3': 0.01,
#    'so2': 14.19,
#    'pm2_5': 66.35,
#    'pm10': 90.87,
#    'nh3': 4.12},
#   'dt': 1737975600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1428.6,
#    'no': 62.59,
#    'no2': 25.36,
#    'o3': 0.04,
#    'so2': 11.92,
#    'pm2_5': 53.07,
#    'pm10': 78.49,
#    'nh3': 3.39},
#   'dt': 1737979200},
#  {'main': {'aqi': 2},
#   'components': {'co': 734.33,
#    'no': 14.75,
#    'no2': 29.13,
#    'o3': 3.98,
#    'so2': 11.33,
#    'pm2_5': 20.91,
#    'pm10': 42.57,
#    'nh3': 4.56},
#   'dt': 1737982800},
#  {'main': {'aqi': 2},
#   'components': {'co': 560.76,
#    'no': 4.19,
#    'no2': 28.45,
#    'o3': 10.82,
#    'so2': 9.54,
#    'pm2_5': 11.99,
#    'pm10': 29.92,
#    'nh3': 4.12},
#   'dt': 1737986400},
#  {'main': {'aqi': 2},
#   'components': {'co': 500.68,
#    'no': 1.76,
#    'no2': 26.73,
#    'o3': 19.31,
#    'so2': 8.7,
#    'pm2_5': 8.94,
#    'pm10': 24.31,
#    'nh3': 4.12},
#   'dt': 1737990000},
#  {'main': {'aqi': 1},
#   'components': {'co': 423.91,
#    'no': 0.44,
#    'no2': 16.11,
#    'o3': 35.05,
#    'so2': 4.95,
#    'pm2_5': 5.35,
#    'pm10': 13.61,
#    'nh3': 2.38},
#   'dt': 1737993600},
#  {'main': {'aqi': 1},
#   'components': {'co': 433.92,
#    'no': 0.19,
#    'no2': 16.11,
#    'o3': 37.91,
#    'so2': 5.01,
#    'pm2_5': 5.23,
#    'pm10': 12.28,
#    'nh3': 2.38},
#   'dt': 1737997200},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.12,
#    'no2': 19.36,
#    'o3': 35.05,
#    'so2': 6.32,
#    'pm2_5': 6.04,
#    'pm10': 13.6,
#    'nh3': 2.91},
#   'dt': 1738000800},
#  {'main': {'aqi': 1},
#   'components': {'co': 514.03,
#    'no': 0.11,
#    'no2': 24.68,
#    'o3': 29.33,
#    'so2': 7.87,
#    'pm2_5': 6.99,
#    'pm10': 15.83,
#    'nh3': 3.42},
#   'dt': 1738004400},
#  {'main': {'aqi': 1},
#   'components': {'co': 567.44,
#    'no': 0.18,
#    'no2': 30.85,
#    'o3': 22.89,
#    'so2': 9.54,
#    'pm2_5': 8.01,
#    'pm10': 18.48,
#    'nh3': 3.67},
#   'dt': 1738008000},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 0.31,
#    'no2': 34.62,
#    'o3': 19.13,
#    'so2': 10.97,
#    'pm2_5': 8.95,
#    'pm10': 20.82,
#    'nh3': 3.67},
#   'dt': 1738011600},
#  {'main': {'aqi': 2},
#   'components': {'co': 674.25,
#    'no': 1.17,
#    'no2': 41.13,
#    'o3': 8.67,
#    'so2': 12.4,
#    'pm2_5': 12.35,
#    'pm10': 26.32,
#    'nh3': 3.39},
#   'dt': 1738015200},
#  {'main': {'aqi': 2},
#   'components': {'co': 794.41,
#    'no': 5.81,
#    'no2': 42.84,
#    'o3': 0.53,
#    'so2': 12.88,
#    'pm2_5': 17.61,
#    'pm10': 33.21,
#    'nh3': 3.07},
#   'dt': 1738018800},
#  {'main': {'aqi': 2},
#   'components': {'co': 921.25,
#    'no': 14.31,
#    'no2': 39.76,
#    'o3': 0.01,
#    'so2': 13.35,
#    'pm2_5': 23.3,
#    'pm10': 39.61,
#    'nh3': 3.2},
#   'dt': 1738022400},
#  {'main': {'aqi': 3},
#   'components': {'co': 1028.06,
#    'no': 22.58,
#    'no2': 37.01,
#    'o3': 0,
#    'so2': 14.07,
#    'pm2_5': 28.96,
#    'pm10': 45.96,
#    'nh3': 3.74},
#   'dt': 1738026000},
#  {'main': {'aqi': 3},
#   'components': {'co': 961.3,
#    'no': 21.68,
#    'no2': 32.22,
#    'o3': 0,
#    'so2': 11.56,
#    'pm2_5': 27.96,
#    'pm10': 44.5,
#    'nh3': 3.14},
#   'dt': 1738029600},
#  {'main': {'aqi': 2},
#   'components': {'co': 767.71,
#    'no': 13.3,
#    'no2': 26.73,
#    'o3': 0.02,
#    'so2': 7.87,
#    'pm2_5': 21.47,
#    'pm10': 36.61,
#    'nh3': 2.09},
#   'dt': 1738033200},
#  {'main': {'aqi': 2},
#   'components': {'co': 574.11,
#    'no': 3.58,
#    'no2': 21.94,
#    'o3': 0.85,
#    'so2': 4.89,
#    'pm2_5': 14.01,
#    'pm10': 26.7,
#    'nh3': 1.36},
#   'dt': 1738036800},
#  {'main': {'aqi': 2},
#   'components': {'co': 480.65,
#    'no': 0.7,
#    'no2': 17.99,
#    'o3': 3.26,
#    'so2': 4.05,
#    'pm2_5': 11.03,
#    'pm10': 22.32,
#    'nh3': 1.24},
#   'dt': 1738040400},
#  {'main': {'aqi': 2},
#   'components': {'co': 453.95,
#    'no': 0.59,
#    'no2': 16.28,
#    'o3': 3.49,
#    'so2': 4.23,
#    'pm2_5': 10.87,
#    'pm10': 21.46,
#    'nh3': 1.35},
#   'dt': 1738044000},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 1.24,
#    'no2': 15.25,
#    'o3': 1.63,
#    'so2': 4.41,
#    'pm2_5': 11.08,
#    'pm10': 21.68,
#    'nh3': 1.41},
#   'dt': 1738047600},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 3.27,
#    'no2': 13.71,
#    'o3': 0.36,
#    'so2': 4.47,
#    'pm2_5': 10.98,
#    'pm10': 22.16,
#    'nh3': 1.41},
#   'dt': 1738051200},
#  {'main': {'aqi': 2},
#   'components': {'co': 494,
#    'no': 10.39,
#    'no2': 12.68,
#    'o3': 0.03,
#    'so2': 5.07,
#    'pm2_5': 11.56,
#    'pm10': 24.37,
#    'nh3': 1.66},
#   'dt': 1738054800},
#  {'main': {'aqi': 2},
#   'components': {'co': 647.54,
#    'no': 25.48,
#    'no2': 12.68,
#    'o3': 0.11,
#    'so2': 6.08,
#    'pm2_5': 13,
#    'pm10': 27.67,
#    'nh3': 1.95},
#   'dt': 1738058400},
#  {'main': {'aqi': 2},
#   'components': {'co': 707.63,
#    'no': 31.74,
#    'no2': 13.54,
#    'o3': 0.67,
#    'so2': 6.2,
#    'pm2_5': 12.03,
#    'pm10': 27.63,
#    'nh3': 1.79},
#   'dt': 1738062000},
#  {'main': {'aqi': 2},
#   'components': {'co': 574.11,
#    'no': 18.55,
#    'no2': 16.28,
#    'o3': 3.89,
#    'so2': 6.08,
#    'pm2_5': 8.37,
#    'pm10': 22.22,
#    'nh3': 2.09},
#   'dt': 1738065600},
#  {'main': {'aqi': 1},
#   'components': {'co': 377.18,
#    'no': 2.71,
#    'no2': 14.4,
#    'o3': 14.31,
#    'so2': 5.07,
#    'pm2_5': 3.94,
#    'pm10': 11.98,
#    'nh3': 2.12},
#   'dt': 1738069200},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 2.12,
#    'no2': 14.74,
#    'o3': 18.42,
#    'so2': 4.89,
#    'pm2_5': 4.24,
#    'pm10': 11.46,
#    'nh3': 1.96},
#   'dt': 1738072800},
#  {'main': {'aqi': 1},
#   'components': {'co': 420.57,
#    'no': 1.82,
#    'no2': 17.65,
#    'o3': 19.85,
#    'so2': 4.89,
#    'pm2_5': 5.41,
#    'pm10': 12.45,
#    'nh3': 1.85},
#   'dt': 1738076400},
#  {'main': {'aqi': 1},
#   'components': {'co': 453.95,
#    'no': 1.29,
#    'no2': 18.85,
#    'o3': 22.71,
#    'so2': 4.47,
#    'pm2_5': 6.8,
#    'pm10': 13.72,
#    'nh3': 1.76},
#   'dt': 1738080000},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.91,
#    'no2': 17.82,
#    'o3': 28.61,
#    'so2': 4.83,
#    'pm2_5': 7.4,
#    'pm10': 14.39,
#    'nh3': 2.03},
#   'dt': 1738083600},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.8,
#    'no2': 18.51,
#    'o3': 30.4,
#    'so2': 5.42,
#    'pm2_5': 7.26,
#    'pm10': 14.66,
#    'nh3': 2.44},
#   'dt': 1738087200},
#  {'main': {'aqi': 1},
#   'components': {'co': 540.73,
#    'no': 2.07,
#    'no2': 25.36,
#    'o3': 25.75,
#    'so2': 7.33,
#    'pm2_5': 8.64,
#    'pm10': 18.18,
#    'nh3': 3.1},
#   'dt': 1738090800},
#  {'main': {'aqi': 2},
#   'components': {'co': 674.25,
#    'no': 3.91,
#    'no2': 38.39,
#    'o3': 13.77,
#    'so2': 9.42,
#    'pm2_5': 11.42,
#    'pm10': 24.23,
#    'nh3': 3.39},
#   'dt': 1738094400},
#  {'main': {'aqi': 2},
#   'components': {'co': 761.03,
#    'no': 5.76,
#    'no2': 45.93,
#    'o3': 4.74,
#    'so2': 11.33,
#    'pm2_5': 13.96,
#    'pm10': 29.56,
#    'nh3': 3.45},
#   'dt': 1738098000},
#  {'main': {'aqi': 2},
#   'components': {'co': 814.44,
#    'no': 8.72,
#    'no2': 45.24,
#    'o3': 0.64,
#    'so2': 12.52,
#    'pm2_5': 16.72,
#    'pm10': 35.81,
#    'nh3': 3.61},
#   'dt': 1738101600},
#  {'main': {'aqi': 2},
#   'components': {'co': 821.11,
#    'no': 12.85,
#    'no2': 36.67,
#    'o3': 0.02,
#    'so2': 11.21,
#    'pm2_5': 18.25,
#    'pm10': 39.9,
#    'nh3': 2.98},
#   'dt': 1738105200},
#  {'main': {'aqi': 2},
#   'components': {'co': 781.06,
#    'no': 14.98,
#    'no2': 28.1,
#    'o3': 0.01,
#    'so2': 8.82,
#    'pm2_5': 17.96,
#    'pm10': 41.48,
#    'nh3': 2.34},
#   'dt': 1738108800},
#  {'main': {'aqi': 2},
#   'components': {'co': 720.98,
#    'no': 16.09,
#    'no2': 20.56,
#    'o3': 0.01,
#    'so2': 6.8,
#    'pm2_5': 16.2,
#    'pm10': 39.95,
#    'nh3': 1.87},
#   'dt': 1738112400},
#  {'main': {'aqi': 2},
#   'components': {'co': 654.22,
#    'no': 16.99,
#    'no2': 15.42,
#    'o3': 0,
#    'so2': 5.13,
#    'pm2_5': 13.85,
#    'pm10': 36.2,
#    'nh3': 1.47},
#   'dt': 1738116000},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 16.54,
#    'no2': 12,
#    'o3': 0,
#    'so2': 4.41,
#    'pm2_5': 12.48,
#    'pm10': 34.14,
#    'nh3': 1.38},
#   'dt': 1738119600},
#  {'main': {'aqi': 2},
#   'components': {'co': 534.06,
#    'no': 13.19,
#    'no2': 10.2,
#    'o3': 0,
#    'so2': 3.82,
#    'pm2_5': 11.52,
#    'pm10': 32.95,
#    'nh3': 1.28},
#   'dt': 1738123200},
#  {'main': {'aqi': 2},
#   'components': {'co': 473.98,
#    'no': 9.39,
#    'no2': 9.85,
#    'o3': 0.01,
#    'so2': 3.58,
#    'pm2_5': 10.64,
#    'pm10': 29.04,
#    'nh3': 1.24},
#   'dt': 1738126800},
#  {'main': {'aqi': 2},
#   'components': {'co': 440.6,
#    'no': 6.93,
#    'no2': 10.2,
#    'o3': 0.02,
#    'so2': 3.73,
#    'pm2_5': 10.19,
#    'pm10': 26.25,
#    'nh3': 1.3},
#   'dt': 1738130400},
#  {'main': {'aqi': 2},
#   'components': {'co': 413.9,
#    'no': 5.64,
#    'no2': 10.45,
#    'o3': 0.04,
#    'so2': 3.87,
#    'pm2_5': 9.88,
#    'pm10': 23.96,
#    'nh3': 1.33},
#   'dt': 1738134000},
#  {'main': {'aqi': 2},
#   'components': {'co': 400.54,
#    'no': 5.76,
#    'no2': 10.45,
#    'o3': 0.05,
#    'so2': 4.17,
#    'pm2_5': 9.39,
#    'pm10': 21.85,
#    'nh3': 1.38},
#   'dt': 1738137600},
#  {'main': {'aqi': 2},
#   'components': {'co': 427.25,
#    'no': 8.83,
#    'no2': 11.48,
#    'o3': 0.03,
#    'so2': 5.25,
#    'pm2_5': 8.67,
#    'pm10': 20.89,
#    'nh3': 1.82},
#   'dt': 1738141200},
#  {'main': {'aqi': 2},
#   'components': {'co': 453.95,
#    'no': 10.84,
#    'no2': 13.2,
#    'o3': 0.39,
#    'so2': 7.09,
#    'pm2_5': 6.88,
#    'pm10': 22.01,
#    'nh3': 2.69},
#   'dt': 1738144800},
#  {'main': {'aqi': 2},
#   'components': {'co': 480.65,
#    'no': 11.74,
#    'no2': 15.25,
#    'o3': 2.64,
#    'so2': 7.57,
#    'pm2_5': 6.09,
#    'pm10': 23.32,
#    'nh3': 2.85},
#   'dt': 1738148400},
#  {'main': {'aqi': 2},
#   'components': {'co': 467.3,
#    'no': 8.27,
#    'no2': 17.99,
#    'o3': 10.1,
#    'so2': 8.11,
#    'pm2_5': 5.49,
#    'pm10': 23.18,
#    'nh3': 3.55},
#   'dt': 1738152000},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 1.84,
#    'no2': 15.94,
#    'o3': 16.27,
#    'so2': 6.08,
#    'pm2_5': 3.37,
#    'pm10': 13.5,
#    'nh3': 2.82},
#   'dt': 1738155600},
#  {'main': {'aqi': 1},
#   'components': {'co': 383.85,
#    'no': 1.79,
#    'no2': 14.4,
#    'o3': 21.64,
#    'so2': 5.84,
#    'pm2_5': 3.62,
#    'pm10': 12.12,
#    'nh3': 2.47},
#   'dt': 1738159200},
#  {'main': {'aqi': 1},
#   'components': {'co': 400.54,
#    'no': 1.61,
#    'no2': 14.74,
#    'o3': 28.61,
#    'so2': 5.6,
#    'pm2_5': 4.21,
#    'pm10': 12.48,
#    'nh3': 2.22},
#   'dt': 1738162800},
#  {'main': {'aqi': 1},
#   'components': {'co': 413.9,
#    'no': 1.16,
#    'no2': 15.08,
#    'o3': 35.41,
#    'so2': 5.01,
#    'pm2_5': 4.78,
#    'pm10': 12.58,
#    'nh3': 1.93},
#   'dt': 1738166400},
#  {'main': {'aqi': 1},
#   'components': {'co': 427.25,
#    'no': 0.87,
#    'no2': 15.59,
#    'o3': 36.12,
#    'so2': 5.36,
#    'pm2_5': 5.27,
#    'pm10': 12.67,
#    'nh3': 2.06},
#   'dt': 1738170000},
#  {'main': {'aqi': 1},
#   'components': {'co': 440.6,
#    'no': 0.62,
#    'no2': 16.28,
#    'o3': 35.76,
#    'so2': 5.66,
#    'pm2_5': 5.58,
#    'pm10': 12.62,
#    'nh3': 2.22},
#   'dt': 1738173600},
#  {'main': {'aqi': 1},
#   'components': {'co': 467.3,
#    'no': 0.63,
#    'no2': 18.68,
#    'o3': 32.9,
#    'so2': 5.9,
#    'pm2_5': 5.81,
#    'pm10': 12.97,
#    'nh3': 2.41},
#   'dt': 1738177200},
#  {'main': {'aqi': 1},
#   'components': {'co': 534.06,
#    'no': 0.71,
#    'no2': 26.39,
#    'o3': 26.11,
#    'so2': 7.75,
#    'pm2_5': 7.09,
#    'pm10': 16.29,
#    'nh3': 3.1},
#   'dt': 1738180800},
#  {'main': {'aqi': 2},
#   'components': {'co': 594.14,
#    'no': 0.38,
#    'no2': 33.59,
#    'o3': 21.28,
#    'so2': 10.01,
#    'pm2_5': 9.17,
#    'pm10': 20.7,
#    'nh3': 3.86},
#   'dt': 1738184400},
#  {'main': {'aqi': 2},
#   'components': {'co': 667.57,
#    'no': 0.36,
#    'no2': 41.13,
#    'o3': 13.05,
#    'so2': 12.64,
#    'pm2_5': 12.8,
#    'pm10': 27.47,
#    'nh3': 4.37},
#   'dt': 1738188000},
#  {'main': {'aqi': 2},
#   'components': {'co': 707.63,
#    'no': 1.34,
#    'no2': 42.5,
#    'o3': 3.89,
#    'so2': 12.52,
#    'pm2_5': 15.49,
#    'pm10': 32.96,
#    'nh3': 3.64},
#   'dt': 1738191600},
#  {'main': {'aqi': 2},
#   'components': {'co': 687.6,
#    'no': 3.05,
#    'no2': 35.64,
#    'o3': 0.95,
#    'so2': 10.13,
#    'pm2_5': 15.38,
#    'pm10': 33.78,
#    'nh3': 2.76},
#   'dt': 1738195200}]

# %%
columns = []

for i in data['list'][0]['components'].keys():
    columns.append(i)

# %%
columns
# Out:
# ['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']

# %%
data = {
    
}

# %%
for i in data['list'][0]['components'].keys():
    i.get()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for i in data['list'][0]['components'].keys():
#       2     i.get()
#
# KeyError: 'list'

# %%
df = pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = pd.DataFrame(d)
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### TO DO
# 1. Montar o dataframe com as colunas e os valores
# 2. Colocar dados de outras localizações
# 3. Escolher um banco de dados (mysql, sqlalchemy, postgresql, mongodb)
# 4. Automatizar processo
