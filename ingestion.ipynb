# %%
import requests
import pandas as pd

# %%
API_KEY = 'b389480e567dc25aa6029df66feda312'

# %%
lat = -23.56134513800555
lon = -46.65586044541178

# %%
url = f'http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={API_KEY}'

# %%
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
#    aqi = data['data']['aqi']
#    descricao = data['data']['forecast']['daily']['pm25']['avg']
#    print(f'{data} {descricao}')
else:
    print(f'Erro na requisição: {response.status_code}')

# %%
data['list']
# Out:
# [{'main': {'aqi': 4},
#   'components': {'co': 1108.17,
#    'no': 2.99,
#    'no2': 58.26,
#    'o3': 0.83,
#    'so2': 22.41,
#    'pm2_5': 62.43,
#    'pm10': 90.22,
#    'nh3': 5.26},
#   'dt': 1737694800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1041.41,
#    'no': 2.24,
#    'no2': 55.52,
#    'o3': 1.4,
#    'so2': 24.08,
#    'pm2_5': 61.05,
#    'pm10': 86.07,
#    'nh3': 5.76},
#   'dt': 1737698400},
#  {'main': {'aqi': 4},
#   'components': {'co': 1054.76,
#    'no': 3.07,
#    'no2': 56.89,
#    'o3': 0.84,
#    'so2': 27.66,
#    'pm2_5': 63.27,
#    'pm10': 88.35,
#    'nh3': 6.59},
#   'dt': 1737702000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1068.12,
#    'no': 5.76,
#    'no2': 55.52,
#    'o3': 0.16,
#    'so2': 27.9,
#    'pm2_5': 65.87,
#    'pm10': 91.65,
#    'nh3': 6.59},
#   'dt': 1737705600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1108.17,
#    'no': 12.29,
#    'no2': 51.41,
#    'o3': 0.01,
#    'so2': 25.75,
# ...

# %%
print(data.keys)
# Out:
# <built-in method keys of dict object at 0x000002B18C1C9B40>

# %%
for item in data['list']:
    print(item)
# Out:
# {'main': {'aqi': 4}, 'components': {'co': 1108.17, 'no': 2.99, 'no2': 58.26, 'o3': 0.83, 'so2': 22.41, 'pm2_5': 62.43, 'pm10': 90.22, 'nh3': 5.26}, 'dt': 1737694800}
# {'main': {'aqi': 4}, 'components': {'co': 1041.41, 'no': 2.24, 'no2': 55.52, 'o3': 1.4, 'so2': 24.08, 'pm2_5': 61.05, 'pm10': 86.07, 'nh3': 5.76}, 'dt': 1737698400}
# {'main': {'aqi': 4}, 'components': {'co': 1054.76, 'no': 3.07, 'no2': 56.89, 'o3': 0.84, 'so2': 27.66, 'pm2_5': 63.27, 'pm10': 88.35, 'nh3': 6.59}, 'dt': 1737702000}
# {'main': {'aqi': 4}, 'components': {'co': 1068.12, 'no': 5.76, 'no2': 55.52, 'o3': 0.16, 'so2': 27.9, 'pm2_5': 65.87, 'pm10': 91.65, 'nh3': 6.59}, 'dt': 1737705600}
# {'main': {'aqi': 4}, 'components': {'co': 1108.17, 'no': 12.29, 'no2': 51.41, 'o3': 0.01, 'so2': 25.75, 'pm2_5': 67.26, 'pm10': 92.74, 'nh3': 6.21}, 'dt': 1737709200}
# ...

# %%
data['list']
# Out:
# [{'main': {'aqi': 4},
#   'components': {'co': 1108.17,
#    'no': 2.99,
#    'no2': 58.26,
#    'o3': 0.83,
#    'so2': 22.41,
#    'pm2_5': 62.43,
#    'pm10': 90.22,
#    'nh3': 5.26},
#   'dt': 1737694800},
#  {'main': {'aqi': 4},
#   'components': {'co': 1041.41,
#    'no': 2.24,
#    'no2': 55.52,
#    'o3': 1.4,
#    'so2': 24.08,
#    'pm2_5': 61.05,
#    'pm10': 86.07,
#    'nh3': 5.76},
#   'dt': 1737698400},
#  {'main': {'aqi': 4},
#   'components': {'co': 1054.76,
#    'no': 3.07,
#    'no2': 56.89,
#    'o3': 0.84,
#    'so2': 27.66,
#    'pm2_5': 63.27,
#    'pm10': 88.35,
#    'nh3': 6.59},
#   'dt': 1737702000},
#  {'main': {'aqi': 4},
#   'components': {'co': 1068.12,
#    'no': 5.76,
#    'no2': 55.52,
#    'o3': 0.16,
#    'so2': 27.9,
#    'pm2_5': 65.87,
#    'pm10': 91.65,
#    'nh3': 6.59},
#   'dt': 1737705600},
#  {'main': {'aqi': 4},
#   'components': {'co': 1108.17,
#    'no': 12.29,
#    'no2': 51.41,
#    'o3': 0.01,
#    'so2': 25.75,
# ...

# %%
columns = []

for i in data['list'][0]['components'].keys():
    columns.append(i)

# %%
columns
# Out:
# ['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']

# %%
data = {
    
}

# %%
df = pd.DataFrame(d)

# %% [markdown]
# ### TO DO
# 1. Montar o dataframe com as colunas e os valores
# 2. Colocar dados de outras localizações
# 3. Escolher um banco de dados (mysql, sqlalchemy, postgresql, mongodb)
# 4. Automatizar processo
