# %%
import requests
# import psycopg2
from datetime import datetime
import pandas as pd
import os

df = pd.read_excel('cities_list.xlsx')

API_KEY = os.getenv('API_KEY')

def get_air_pollution_Data(API_KEY, lat, lon):
    
    url = f'http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={API_KEY}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f'Error requisition: {response.status_code}')
        return None

# %%
df = df.rename(columns={"name": "City", "lon": "Longitude", "lat": "Latitude", "country": "Country"})

# %%
df = df.rename(columns={"name": "City", "lon": "Longitude", "lat": "Latitude", "country": "Country"})

# %%
df
# Out:
#               City  Longitude  Latitude               Country
# 0          Abidjan   -4.00167   5.35444           Ivory Coast
# 1        Abu Dhabi   54.39696  24.45118  United Arab Emirates
# 2            Abuja    7.49508   9.05785               Nigeria
# 3            Accra   -0.19690   5.55602                 Ghana
# 4      Addis Ababa   38.74689   9.02497              Ethiopia
# ..             ...        ...       ...                   ...
# 366        Yaounde   11.51667   3.86667              Cameroon
# 367  Yekaterinburg   60.61220  56.85190                Russia
# 368        Yerevan   44.51361  40.18111               Armenia
# 369       Yokohama  139.65000  35.43333                 Japan
# 370         Zagreb   15.97798  45.81444               Croatia
#
# [371 rows x 4 columns]

# %%
print(df[['Latitude', 'Longitude']])
# Out:
#      Latitude  Longitude
# 0     5.35444   -4.00167
# 1    24.45118   54.39696
# 2     9.05785    7.49508
# 3     5.55602   -0.19690
# 4     9.02497   38.74689
# ..        ...        ...
# 366   3.86667   11.51667
# 367  56.85190   60.61220
# 368  40.18111   44.51361
# 369  35.43333  139.65000
# 370  45.81444   15.97798
#
# [371 rows x 2 columns]

# %%
get_air_pollution_Data(API_KEY, 5.35444, -4.00167)
# Out:
# {'coord': {'lon': -4.0017, 'lat': 5.3544},
#  'list': [{'main': {'aqi': 2},
#    'components': {'co': 453.95,
#     'no': 0,
#     'no2': 2.06,
#     'o3': 20.74,
#     'so2': 1.07,
#     'pm2_5': 3.46,
#     'pm10': 40.72,
#     'nh3': 3.42},
#    'dt': 1738699200},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0,
#     'no2': 1.71,
#     'o3': 20.03,
#     'so2': 0.89,
#     'pm2_5': 3.17,
#     'pm10': 35.96,
#     'nh3': 2.6},
#    'dt': 1738702800},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0,
#     'no2': 1.59,
#     'o3': 21.46,
#     'so2': 0.83,
#     'pm2_5': 3.17,
#     'pm10': 31.42,
#     'nh3': 2.28},
#    'dt': 1738706400},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 0,
#     'no2': 1.39,
#     'o3': 22.89,
#     'so2': 0.73,
#     'pm2_5': 2.96,
#     'pm10': 28.35,
#     'nh3': 2.03},
#    'dt': 1738710000},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0,
#     'no2': 1.04,
#     'o3': 23.6,
#     'so2': 0.57,
#     'pm2_5': 2.46,
#     'pm10': 25.69,
#     'nh3': 1.68},
#    'dt': 1738713600},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0,
#     'no2': 0.88,
#     'o3': 22.89,
#     'so2': 0.48,
#     'pm2_5': 2.31,
#     'pm10': 23.2,
#     'nh3': 1.39},
#    'dt': 1738717200},
#   {'main': {'aqi': 2},
#    'components': {'co': 407.22,
#     'no': 0,
#     'no2': 0.91,
#     'o3': 21.46,
#     'so2': 0.5,
#     'pm2_5': 2.55,
#     'pm10': 22.82,
#     'nh3': 1.41},
#    'dt': 1738720800},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0,
#     'no2': 1,
#     'o3': 19.49,
#     'so2': 0.57,
#     'pm2_5': 2.92,
#     'pm10': 24.53,
#     'nh3': 1.65},
#    'dt': 1738724400},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0,
#     'no2': 1.04,
#     'o3': 17.88,
#     'so2': 0.6,
#     'pm2_5': 3.14,
#     'pm10': 26.24,
#     'nh3': 1.82},
#    'dt': 1738728000},
#   {'main': {'aqi': 2},
#    'components': {'co': 410.56,
#     'no': 0.01,
#     'no2': 1.02,
#     'o3': 16.45,
#     'so2': 0.58,
#     'pm2_5': 3.13,
#     'pm10': 26.21,
#     'nh3': 1.76},
#    'dt': 1738731600},
#   {'main': {'aqi': 2},
#    'components': {'co': 410.56,
#     'no': 0.01,
#     'no2': 1.15,
#     'o3': 15.38,
#     'so2': 0.61,
#     'pm2_5': 3.21,
#     'pm10': 26.05,
#     'nh3': 1.77},
#    'dt': 1738735200},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.04,
#     'no2': 2.16,
#     'o3': 13.59,
#     'so2': 0.87,
#     'pm2_5': 4.21,
#     'pm10': 28.35,
#     'nh3': 2.28},
#    'dt': 1738738800},
#   {'main': {'aqi': 2},
#    'components': {'co': 467.3,
#     'no': 0.28,
#     'no2': 2.96,
#     'o3': 12.7,
#     'so2': 1.07,
#     'pm2_5': 4.94,
#     'pm10': 32.17,
#     'nh3': 2.79},
#    'dt': 1738742400},
#   {'main': {'aqi': 2},
#    'components': {'co': 453.95,
#     'no': 0.5,
#     'no2': 2.25,
#     'o3': 18.06,
#     'so2': 1.06,
#     'pm2_5': 4.58,
#     'pm10': 33.47,
#     'nh3': 3.14},
#    'dt': 1738746000},
#   {'main': {'aqi': 2},
#    'components': {'co': 410.56,
#     'no': 0.23,
#     'no2': 1.06,
#     'o3': 24.32,
#     'so2': 0.79,
#     'pm2_5': 3.18,
#     'pm10': 25.01,
#     'nh3': 2.79},
#    'dt': 1738749600},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.18,
#     'no2': 0.81,
#     'o3': 27.18,
#     'so2': 0.75,
#     'pm2_5': 3,
#     'pm10': 22.99,
#     'nh3': 2.76},
#    'dt': 1738753200},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 0.14,
#     'no2': 0.7,
#     'o3': 28.61,
#     'so2': 0.69,
#     'pm2_5': 2.89,
#     'pm10': 22.32,
#     'nh3': 2.66},
#    'dt': 1738756800},
#   {'main': {'aqi': 2},
#    'components': {'co': 380.52,
#     'no': 0.1,
#     'no2': 0.54,
#     'o3': 31.83,
#     'so2': 0.51,
#     'pm2_5': 4.77,
#     'pm10': 25.24,
#     'nh3': 2.12},
#    'dt': 1738760400},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.09,
#     'no2': 0.57,
#     'o3': 36.12,
#     'so2': 0.51,
#     'pm2_5': 7.05,
#     'pm10': 29.87,
#     'nh3': 2.22},
#    'dt': 1738764000},
#   {'main': {'aqi': 2},
#    'components': {'co': 387.19,
#     'no': 0.09,
#     'no2': 0.65,
#     'o3': 35.41,
#     'so2': 0.56,
#     'pm2_5': 6.53,
#     'pm10': 28.17,
#     'nh3': 2.34},
#    'dt': 1738767600},
#   {'main': {'aqi': 2},
#    'components': {'co': 397.21,
#     'no': 0.11,
#     'no2': 0.81,
#     'o3': 30.04,
#     'so2': 0.7,
#     'pm2_5': 4.98,
#     'pm10': 28.69,
#     'nh3': 2.79},
#    'dt': 1738771200},
#   {'main': {'aqi': 2},
#    'components': {'co': 407.22,
#     'no': 0.16,
#     'no2': 1.14,
#     'o3': 25.39,
#     'so2': 0.82,
#     'pm2_5': 3.82,
#     'pm10': 30.11,
#     'nh3': 3.1},
#    'dt': 1738774800},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0.11,
#     'no2': 1.59,
#     'o3': 22.89,
#     'so2': 0.83,
#     'pm2_5': 3.63,
#     'pm10': 29.8,
#     'nh3': 2.95},
#    'dt': 1738778400},
#   {'main': {'aqi': 2},
#    'components': {'co': 417.23,
#     'no': 0.01,
#     'no2': 1.84,
#     'o3': 20.56,
#     'so2': 0.92,
#     'pm2_5': 3.9,
#     'pm10': 30.32,
#     'nh3': 2.91},
#    'dt': 1738782000},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.01,
#     'no2': 1.61,
#     'o3': 19.49,
#     'so2': 0.86,
#     'pm2_5': 3.74,
#     'pm10': 29.66,
#     'nh3': 2.57},
#    'dt': 1738785600},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.01,
#     'no2': 1.33,
#     'o3': 19.49,
#     'so2': 0.73,
#     'pm2_5': 3.49,
#     'pm10': 27.64,
#     'nh3': 2.09},
#    'dt': 1738789200},
#   {'main': {'aqi': 2},
#    'components': {'co': 380.52,
#     'no': 0.01,
#     'no2': 1.24,
#     'o3': 20.21,
#     'so2': 0.7,
#     'pm2_5': 3.72,
#     'pm10': 26.4,
#     'nh3': 1.95},
#    'dt': 1738792800},
#   {'main': {'aqi': 2},
#    'components': {'co': 377.18,
#     'no': 0,
#     'no2': 1.13,
#     'o3': 20.39,
#     'so2': 0.64,
#     'pm2_5': 3.55,
#     'pm10': 24.8,
#     'nh3': 1.84},
#    'dt': 1738796400},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.17,
#     'no': 0,
#     'no2': 0.87,
#     'o3': 20.03,
#     'so2': 0.52,
#     'pm2_5': 2.94,
#     'pm10': 21.98,
#     'nh3': 1.6},
#    'dt': 1738800000},
#   {'main': {'aqi': 1},
#    'components': {'co': 357.15,
#     'no': 0,
#     'no2': 0.69,
#     'o3': 19.67,
#     'so2': 0.46,
#     'pm2_5': 2.65,
#     'pm10': 19.67,
#     'nh3': 1.47},
#    'dt': 1738803600},
#   {'main': {'aqi': 1},
#    'components': {'co': 357.15,
#     'no': 0,
#     'no2': 0.63,
#     'o3': 18.95,
#     'so2': 0.47,
#     'pm2_5': 2.64,
#     'pm10': 19.15,
#     'nh3': 1.5},
#    'dt': 1738807200},
#   {'main': {'aqi': 1},
#    'components': {'co': 357.15,
#     'no': 0,
#     'no2': 0.62,
#     'o3': 18.24,
#     'so2': 0.51,
#     'pm2_5': 2.7,
#     'pm10': 19.97,
#     'nh3': 1.62},
#    'dt': 1738810800},
#   {'main': {'aqi': 2},
#    'components': {'co': 360.49,
#     'no': 0,
#     'no2': 0.64,
#     'o3': 17.52,
#     'so2': 0.53,
#     'pm2_5': 2.79,
#     'pm10': 21.02,
#     'nh3': 1.65},
#    'dt': 1738814400},
#   {'main': {'aqi': 2},
#    'components': {'co': 363.83,
#     'no': 0,
#     'no2': 0.7,
#     'o3': 17.17,
#     'so2': 0.54,
#     'pm2_5': 2.91,
#     'pm10': 21.94,
#     'nh3': 1.65},
#    'dt': 1738818000},
#   {'main': {'aqi': 2},
#    'components': {'co': 370.5,
#     'no': 0.01,
#     'no2': 0.9,
#     'o3': 16.81,
#     'so2': 0.59,
#     'pm2_5': 3.14,
#     'pm10': 23.48,
#     'nh3': 1.74},
#    'dt': 1738821600},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.02,
#     'no2': 1.86,
#     'o3': 15.38,
#     'so2': 0.85,
#     'pm2_5': 4.1,
#     'pm10': 27.89,
#     'nh3': 2.31},
#    'dt': 1738825200},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0.22,
#     'no2': 2.44,
#     'o3': 14.84,
#     'so2': 0.98,
#     'pm2_5': 4.58,
#     'pm10': 32.39,
#     'nh3': 2.76},
#    'dt': 1738828800},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.4,
#     'no2': 1.76,
#     'o3': 19.85,
#     'so2': 0.92,
#     'pm2_5': 4.24,
#     'pm10': 32.65,
#     'nh3': 2.88},
#    'dt': 1738832400},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.17,
#     'no': 0.19,
#     'no2': 0.88,
#     'o3': 24.68,
#     'so2': 0.62,
#     'pm2_5': 3.36,
#     'pm10': 22.66,
#     'nh3': 2.25},
#    'dt': 1738836000},
#   {'main': {'aqi': 2},
#    'components': {'co': 370.5,
#     'no': 0.12,
#     'no2': 0.79,
#     'o3': 26.46,
#     'so2': 0.6,
#     'pm2_5': 3.52,
#     'pm10': 21.57,
#     'nh3': 2.31},
#    'dt': 1738839600},
#   {'main': {'aqi': 2},
#    'components': {'co': 370.5,
#     'no': 0.06,
#     'no2': 0.87,
#     'o3': 25.75,
#     'so2': 0.61,
#     'pm2_5': 3.39,
#     'pm10': 21.61,
#     'nh3': 2.38},
#    'dt': 1738843200},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.17,
#     'no': 0.05,
#     'no2': 0.8,
#     'o3': 25.03,
#     'so2': 0.53,
#     'pm2_5': 3.14,
#     'pm10': 20.32,
#     'nh3': 2.06},
#    'dt': 1738846800},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.17,
#     'no': 0.08,
#     'no2': 0.68,
#     'o3': 26.46,
#     'so2': 0.52,
#     'pm2_5': 3.13,
#     'pm10': 19.8,
#     'nh3': 2.03},
#    'dt': 1738850400},
#   {'main': {'aqi': 2},
#    'components': {'co': 370.5,
#     'no': 0.1,
#     'no2': 0.62,
#     'o3': 27.54,
#     'so2': 0.54,
#     'pm2_5': 3.16,
#     'pm10': 20.2,
#     'nh3': 2.09},
#    'dt': 1738854000},
#   {'main': {'aqi': 2},
#    'components': {'co': 377.18,
#     'no': 0.12,
#     'no2': 0.71,
#     'o3': 27.18,
#     'so2': 0.62,
#     'pm2_5': 3.36,
#     'pm10': 23.8,
#     'nh3': 2.31},
#    'dt': 1738857600},
#   {'main': {'aqi': 2},
#    'components': {'co': 393.87,
#     'no': 0.14,
#     'no2': 1.07,
#     'o3': 26.46,
#     'so2': 0.71,
#     'pm2_5': 3.72,
#     'pm10': 27.47,
#     'nh3': 2.57},
#    'dt': 1738861200},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.09,
#     'no2': 1.56,
#     'o3': 24.32,
#     'so2': 0.75,
#     'pm2_5': 4.11,
#     'pm10': 27.9,
#     'nh3': 2.57},
#    'dt': 1738864800},
#   {'main': {'aqi': 2},
#    'components': {'co': 420.57,
#     'no': 0.01,
#     'no2': 1.86,
#     'o3': 23.25,
#     'so2': 0.86,
#     'pm2_5': 5.01,
#     'pm10': 29.93,
#     'nh3': 2.82},
#    'dt': 1738868400},
#   {'main': {'aqi': 2},
#    'components': {'co': 423.91,
#     'no': 0,
#     'no2': 1.76,
#     'o3': 23.25,
#     'so2': 0.89,
#     'pm2_5': 5.61,
#     'pm10': 32.02,
#     'nh3': 2.76},
#    'dt': 1738872000},
#   {'main': {'aqi': 2},
#    'components': {'co': 420.57,
#     'no': 0,
#     'no2': 1.54,
#     'o3': 23.6,
#     'so2': 0.82,
#     'pm2_5': 5.32,
#     'pm10': 31.31,
#     'nh3': 2.44},
#    'dt': 1738875600},
#   {'main': {'aqi': 2},
#    'components': {'co': 420.57,
#     'no': 0,
#     'no2': 1.5,
#     'o3': 22.89,
#     'so2': 0.82,
#     'pm2_5': 4.78,
#     'pm10': 29.54,
#     'nh3': 2.34},
#    'dt': 1738879200},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0,
#     'no2': 1.39,
#     'o3': 21.99,
#     'so2': 0.75,
#     'pm2_5': 4.04,
#     'pm10': 27.72,
#     'nh3': 2.12},
#    'dt': 1738882800},
#   {'main': {'aqi': 2},
#    'components': {'co': 397.21,
#     'no': 0,
#     'no2': 1.06,
#     'o3': 21.46,
#     'so2': 0.6,
#     'pm2_5': 3.2,
#     'pm10': 25.02,
#     'nh3': 1.79},
#    'dt': 1738886400},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0,
#     'no2': 0.78,
#     'o3': 20.92,
#     'so2': 0.49,
#     'pm2_5': 2.73,
#     'pm10': 22.62,
#     'nh3': 1.57},
#    'dt': 1738890000},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0,
#     'no2': 0.66,
#     'o3': 20.56,
#     'so2': 0.47,
#     'pm2_5': 2.57,
#     'pm10': 21.06,
#     'nh3': 1.52},
#    'dt': 1738893600},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0,
#     'no2': 0.62,
#     'o3': 20.03,
#     'so2': 0.49,
#     'pm2_5': 2.52,
#     'pm10': 20.64,
#     'nh3': 1.55},
#    'dt': 1738897200},
#   {'main': {'aqi': 2},
#    'components': {'co': 387.19,
#     'no': 0,
#     'no2': 0.66,
#     'o3': 19.49,
#     'so2': 0.5,
#     'pm2_5': 2.61,
#     'pm10': 20.79,
#     'nh3': 1.49},
#    'dt': 1738900800},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 0,
#     'no2': 0.8,
#     'o3': 18.77,
#     'so2': 0.53,
#     'pm2_5': 2.85,
#     'pm10': 21.67,
#     'nh3': 1.55},
#    'dt': 1738904400},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.01,
#     'no2': 1.14,
#     'o3': 18.06,
#     'so2': 0.61,
#     'pm2_5': 3.27,
#     'pm10': 24.08,
#     'nh3': 1.82},
#    'dt': 1738908000},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.02,
#     'no2': 2.49,
#     'o3': 16.27,
#     'so2': 0.95,
#     'pm2_5': 4.75,
#     'pm10': 28.73,
#     'nh3': 2.53},
#    'dt': 1738911600},
#   {'main': {'aqi': 2},
#    'components': {'co': 460.63,
#     'no': 0.29,
#     'no2': 3.26,
#     'o3': 15.74,
#     'so2': 1.1,
#     'pm2_5': 5.51,
#     'pm10': 32.22,
#     'nh3': 2.88},
#    'dt': 1738915200},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.48,
#     'no2': 2.19,
#     'o3': 21.1,
#     'so2': 0.98,
#     'pm2_5': 4.72,
#     'pm10': 31.35,
#     'nh3': 2.91},
#    'dt': 1738918800},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.21,
#     'no2': 1,
#     'o3': 25.75,
#     'so2': 0.84,
#     'pm2_5': 3.27,
#     'pm10': 26.12,
#     'nh3': 2.91},
#    'dt': 1738922400},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0.16,
#     'no2': 1.01,
#     'o3': 27.9,
#     'so2': 1.1,
#     'pm2_5': 3.63,
#     'pm10': 30.96,
#     'nh3': 3.77},
#    'dt': 1738926000},
#   {'main': {'aqi': 2},
#    'components': {'co': 460.63,
#     'no': 0.13,
#     'no2': 1.15,
#     'o3': 27.9,
#     'so2': 1.31,
#     'pm2_5': 3.88,
#     'pm10': 32.48,
#     'nh3': 4.31},
#    'dt': 1738929600},
#   {'main': {'aqi': 2},
#    'components': {'co': 460.63,
#     'no': 0.12,
#     'no2': 1.17,
#     'o3': 26.46,
#     'so2': 1.25,
#     'pm2_5': 3.54,
#     'pm10': 29.28,
#     'nh3': 4.18},
#    'dt': 1738933200},
#   {'main': {'aqi': 2},
#    'components': {'co': 447.27,
#     'no': 0.13,
#     'no2': 1.08,
#     'o3': 26.82,
#     'so2': 1.19,
#     'pm2_5': 3.17,
#     'pm10': 28.22,
#     'nh3': 4.24},
#    'dt': 1738936800},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.14,
#     'no2': 1.02,
#     'o3': 27.9,
#     'so2': 1.07,
#     'pm2_5': 2.83,
#     'pm10': 27.27,
#     'nh3': 4.12},
#    'dt': 1738940400},
#   {'main': {'aqi': 2},
#    'components': {'co': 417.23,
#     'no': 0.16,
#     'no2': 1.05,
#     'o3': 27.54,
#     'so2': 0.93,
#     'pm2_5': 2.63,
#     'pm10': 30.69,
#     'nh3': 3.48},
#    'dt': 1738944000},
#   {'main': {'aqi': 2},
#    'components': {'co': 423.91,
#     'no': 0.21,
#     'no2': 1.52,
#     'o3': 27.18,
#     'so2': 1.01,
#     'pm2_5': 3.06,
#     'pm10': 38.13,
#     'nh3': 3.64},
#    'dt': 1738947600},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 0.16,
#     'no2': 2.25,
#     'o3': 23.96,
#     'so2': 1.06,
#     'pm2_5': 3.45,
#     'pm10': 40.03,
#     'nh3': 3.55},
#    'dt': 1738951200},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0.01,
#     'no2': 2.72,
#     'o3': 19.13,
#     'so2': 1.19,
#     'pm2_5': 4,
#     'pm10': 40.25,
#     'nh3': 3.71},
#    'dt': 1738954800},
#   {'main': {'aqi': 2},
#    'components': {'co': 423.91,
#     'no': 0.01,
#     'no2': 2.4,
#     'o3': 16.81,
#     'so2': 1.16,
#     'pm2_5': 4.02,
#     'pm10': 36.58,
#     'nh3': 3.42},
#    'dt': 1738958400},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.01,
#     'no2': 1.99,
#     'o3': 16.09,
#     'so2': 1.01,
#     'pm2_5': 3.55,
#     'pm10': 32.6,
#     'nh3': 2.88},
#    'dt': 1738962000},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.01,
#     'no2': 1.86,
#     'o3': 15.91,
#     'so2': 0.98,
#     'pm2_5': 3.5,
#     'pm10': 29.69,
#     'nh3': 2.69},
#    'dt': 1738965600},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.01,
#     'no2': 1.84,
#     'o3': 16.09,
#     'so2': 0.95,
#     'pm2_5': 3.45,
#     'pm10': 28.22,
#     'nh3': 2.53},
#    'dt': 1738969200},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.01,
#     'no2': 1.48,
#     'o3': 16.63,
#     'so2': 0.77,
#     'pm2_5': 2.83,
#     'pm10': 25.76,
#     'nh3': 2.12},
#    'dt': 1738972800},
#   {'main': {'aqi': 2},
#    'components': {'co': 357.15,
#     'no': 0,
#     'no2': 1.01,
#     'o3': 17.17,
#     'so2': 0.54,
#     'pm2_5': 2.22,
#     'pm10': 22.97,
#     'nh3': 1.6},
#    'dt': 1738976400},
#   {'main': {'aqi': 2},
#    'components': {'co': 343.8,
#     'no': 0,
#     'no2': 0.79,
#     'o3': 17.52,
#     'so2': 0.44,
#     'pm2_5': 2.05,
#     'pm10': 20.25,
#     'nh3': 1.38},
#    'dt': 1738980000},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0,
#     'no2': 0.76,
#     'o3': 17.7,
#     'so2': 0.43,
#     'pm2_5': 2.13,
#     'pm10': 18.51,
#     'nh3': 1.36},
#    'dt': 1738983600},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0,
#     'no2': 0.75,
#     'o3': 17.88,
#     'so2': 0.43,
#     'pm2_5': 2.19,
#     'pm10': 18.13,
#     'nh3': 1.35},
#    'dt': 1738987200},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0,
#     'no2': 0.77,
#     'o3': 18.06,
#     'so2': 0.44,
#     'pm2_5': 2.25,
#     'pm10': 18.53,
#     'nh3': 1.38},
#    'dt': 1738990800},
#   {'main': {'aqi': 1},
#    'components': {'co': 350.48,
#     'no': 0,
#     'no2': 0.93,
#     'o3': 18.24,
#     'so2': 0.48,
#     'pm2_5': 2.46,
#     'pm10': 19.86,
#     'nh3': 1.49},
#    'dt': 1738994400},
#   {'main': {'aqi': 2},
#    'components': {'co': 380.52,
#     'no': 0.01,
#     'no2': 1.76,
#     'o3': 17.88,
#     'so2': 0.72,
#     'pm2_5': 3.5,
#     'pm10': 23.03,
#     'nh3': 2},
#    'dt': 1738998000},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.17,
#     'no2': 2.31,
#     'o3': 18.24,
#     'so2': 0.89,
#     'pm2_5': 4.26,
#     'pm10': 25.91,
#     'nh3': 2.5},
#    'dt': 1739001600},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 0.29,
#     'no2': 1.69,
#     'o3': 22.89,
#     'so2': 0.85,
#     'pm2_5': 4.04,
#     'pm10': 27.13,
#     'nh3': 2.76},
#    'dt': 1739005200},
#   {'main': {'aqi': 2},
#    'components': {'co': 363.83,
#     'no': 0.15,
#     'no2': 0.98,
#     'o3': 26.82,
#     'so2': 0.72,
#     'pm2_5': 3.18,
#     'pm10': 22.54,
#     'nh3': 2.5},
#    'dt': 1739008800},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.15,
#     'no2': 1.08,
#     'o3': 28.61,
#     'so2': 0.92,
#     'pm2_5': 3.75,
#     'pm10': 24.17,
#     'nh3': 3.1},
#    'dt': 1739012400},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.9,
#     'no': 0.15,
#     'no2': 1.26,
#     'o3': 29.68,
#     'so2': 1.18,
#     'pm2_5': 4.4,
#     'pm10': 25.34,
#     'nh3': 3.86},
#    'dt': 1739016000},
#   {'main': {'aqi': 2},
#    'components': {'co': 410.56,
#     'no': 0.14,
#     'no2': 1.25,
#     'o3': 29.68,
#     'so2': 1.13,
#     'pm2_5': 4.27,
#     'pm10': 24.58,
#     'nh3': 3.74},
#    'dt': 1739019600},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 0.13,
#     'no2': 1.09,
#     'o3': 29.68,
#     'so2': 1,
#     'pm2_5': 3.65,
#     'pm10': 24.53,
#     'nh3': 3.42},
#    'dt': 1739023200},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.17,
#     'no': 0.11,
#     'no2': 0.91,
#     'o3': 29.68,
#     'so2': 0.89,
#     'pm2_5': 3,
#     'pm10': 22.87,
#     'nh3': 3.1},
#    'dt': 1739026800},
#   {'main': {'aqi': 2},
#    'components': {'co': 343.8,
#     'no': 0.11,
#     'no2': 0.85,
#     'o3': 28.61,
#     'so2': 0.75,
#     'pm2_5': 2.56,
#     'pm10': 22.25,
#     'nh3': 2.69},
#    'dt': 1739030400},
#   {'main': {'aqi': 2},
#    'components': {'co': 350.48,
#     'no': 0.14,
#     'no2': 1.16,
#     'o3': 28.25,
#     'so2': 0.8,
#     'pm2_5': 2.8,
#     'pm10': 27.11,
#     'nh3': 2.88},
#    'dt': 1739034000},
#   {'main': {'aqi': 2},
#    'components': {'co': 357.15,
#     'no': 0.1,
#     'no2': 1.65,
#     'o3': 26.11,
#     'so2': 0.83,
#     'pm2_5': 3.03,
#     'pm10': 29.26,
#     'nh3': 2.88},
#    'dt': 1739037600},
#   {'main': {'aqi': 2},
#    'components': {'co': 373.84,
#     'no': 0.01,
#     'no2': 2.04,
#     'o3': 23.25,
#     'so2': 0.93,
#     'pm2_5': 3.48,
#     'pm10': 31.21,
#     'nh3': 3.07},
#    'dt': 1739041200}]}

# %%
for index, row in df.iterrows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for index, row in df.iterrows:
#       2     print(row['Latitude'])
#
# TypeError: 'method' object is not iterable

# %%
df['PM_2.5'] = raw_df['list'][0]['components'].get('co')

# %%
df['aqi'] = raw_df['list'][0].get('main').get('aqi')
df['CO'] = raw_df['list'][0]['components'].get('co')
df['NO'] = raw_df['list'][0]['components'].get('no')
df['O3'] = raw_df['list'][0]['components'].get('co')
df['SO2'] = raw_df['list'][0]['components'].get('co')
df['O3'] = raw_df['list'][0]['components'].get('co')
df['SO2'] = raw_df['list'][0]['components'].get('co')
df['PM_2.5'] = raw_df['list'][0]['components'].get('co')
df['PM_10'] = raw_df['list'][0]['components'].get('co')
df['NH3'] = raw_df['list'][0]['components'].get('co')
df['dateTime'] = raw_df['list'][0].get('dt')

# %%
for items in
# Out:
# {'main': {'aqi': 3},
#  'components': {'co': 761.03,
#   'no': 40.68,
#   'no2': 94.59,
#   'o3': 2.1,
#   'so2': 13.23,
#   'pm2_5': 42.65,
#   'pm10': 56.47,
#   'nh3': 2.19},
#  'dt': 1738620000}

# %%
df
# Out:
#               City  Longitude  Latitude               Country  aqi      CO  \
# 0          Abidjan   -4.00167   5.35444           Ivory Coast    3  761.03
# 1        Abu Dhabi   54.39696  24.45118  United Arab Emirates    3  761.03
# 2            Abuja    7.49508   9.05785               Nigeria    3  761.03
# 3            Accra   -0.19690   5.55602                 Ghana    3  761.03
# 4      Addis Ababa   38.74689   9.02497              Ethiopia    3  761.03
# ..             ...        ...       ...                   ...  ...     ...
# 366        Yaounde   11.51667   3.86667              Cameroon    3  761.03
# 367  Yekaterinburg   60.61220  56.85190                Russia    3  761.03
# 368        Yerevan   44.51361  40.18111               Armenia    3  761.03
# 369       Yokohama  139.65000  35.43333                 Japan    3  761.03
# 370         Zagreb   15.97798  45.81444               Croatia    3  761.03
#
#      PM_2.5 dateTime
# 0    761.03      NaN
# 1    761.03      NaN
# 2    761.03      NaN
# 3    761.03      NaN
# 4    761.03      NaN
# ..      ...      ...
# 366  761.03      NaN
# 367  761.03      NaN
# 368  761.03      NaN
# 369  761.03      NaN
# 370  761.03      NaN
#
# [371 rows x 8 columns]

# %%
rows = []

for item in df:
    aqi = item['main']['aqi']
    components = item[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 rows = []
#       3 for item in df:
# ----> 4     aqi = item['main']['aqi']
#       5     components = item[0]
#
# TypeError: string indices must be integers, not 'str'

# %%
row = {
    'aqi':aqi,
    'co':,
    'no':,
    'no2':,
    'o3':,
    'so2':,
    'pm2_5':,
    'pm1':,
    'nh3':

}
# Out:
#   Cell In[28], line 3
#     'co':,
#         ^
# SyntaxError: expression expected after dictionary key and ':'
